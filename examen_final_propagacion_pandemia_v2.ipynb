# %% [markdown]
# # Examen Final: Pronóstico de propagación de pandemia en EE.UU. usando modelos de series de tiempo
#
# ## Objetivo
#
# Este notebook tiene como objetivo predecir la **propagación de la pandemia de COVID-19** en los estados de EE.UU., basándose en los datos de carga viral en aguas residuales. Usaremos modelos de series de tiempo como **LSTM** y **Transformer** para hacer predicciones sobre la evolución futura de la pandemia, con un enfoque de propagación entre estados utilizando una **matriz de adyacencia**.
#
# ### Fase 1: Definición del problema
# 1. **Predicción por Estado:** Entrenaremos un modelo generalizado usando datos de un estado (inicialmente Nueva York) y lo aplicaremos a todos los estados.
# 2. **Umbral de Riesgo:** Definiremos un umbral para identificar qué estados están en riesgo de entrar en una pandemia.
# 3. **Propagación a Estados Adyacentes:** Usaremos una matriz de adyacencia para simular cómo los estados vecinos influencian la propagación del virus.
# 4. **Modelo de Propagación Ajustado:** Entrenaremos el modelo ajustado para incluir el efecto de la proximidad geográfica entre los estados.
#
# ### Fase 2: Implementación técnica
# 1. Descargaremos los datos de **CDC Wastewater** utilizando la API del **National Wastewater Surveillance System (NWSS)**.
# 2. Limpieza y exploración de los datos, convirtiéndolos en una serie de tiempo adecuada para entrenamiento.
# 3. Entrenamiento de los modelos **LSTM** y **Transformer** para hacer predicciones de la carga viral.
# 4. Evaluación del rendimiento del modelo usando **MAE, RMSE y MAPE**.
# 5. Pronóstico para los próximos **30 días** y propagación entre estados adyacentes.
#
# Notebook plantilla con estructura lista para:
# - Construir serie de carga viral en aguas residuales (CDC NWSS).
# - Hacer split temporal train/val/test sin fuga.
# - Escalar solo con train y aplicar a val/test.
# - Crear ventanas deslizantes por split.
# - Entrenar LSTM, comparar vs baseline y hacer pronóstico futuro.
# - Extender a propagación entre estados con matriz de adyacencia (TODO).

# %% [markdown]
# ## 1. Imports, configuración de paths y seeds

# %%
import os
import random
from pathlib import Path
from typing import Tuple, Dict, List

import numpy as np
import pandas as pd
import plotly.graph_objects as go
import requests

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam    
from tensorflow.keras.layers import (
    Input,
    MultiHeadAttention,
    LayerNormalization,
    GlobalAveragePooling1D,
    Dense,
    Dropout,
)
from tensorflow.keras import Model


# Paths base
PROJECT_ROOT = Path('.')
DATA_DIR = PROJECT_ROOT / 'data'
LANDING_DIR = DATA_DIR / 'landing'
PROCESSED_DIR = DATA_DIR / 'processed'
FIGURES_DIR = PROJECT_ROOT / 'figures'
MODELS_DIR = PROJECT_ROOT / 'models'

for d in (DATA_DIR, LANDING_DIR, PROCESSED_DIR, FIGURES_DIR, MODELS_DIR):
    d.mkdir(parents=True, exist_ok=True)

# Seed global
GLOBAL_SEED = 42

def set_global_seed(seed: int = 42):
    global GLOBAL_SEED
    GLOBAL_SEED = seed
    random.seed(seed)
    np.random.seed(seed)

set_global_seed(GLOBAL_SEED)
print(f'Seed global fijada en {GLOBAL_SEED}')
print('PROJECT_ROOT:', PROJECT_ROOT.resolve())
# Out:
# Seed global fijada en 42
# PROJECT_ROOT: C:\Users\esteb\apps\Wastewater-SARS-CoV-2

# %% [markdown]
# ## 2. Helpers: ventanas, métricas, gráficas y forecasting

# %%
def create_sliding_windows(
    series: np.ndarray,
    window_size: int,
    horizon: int = 1,
    stride: int = 1,
) -> Tuple[np.ndarray, np.ndarray]:
    """Crea ventanas deslizantes sobre una serie ya escalada o cruda.
    Se asume que se usa con un split (train / val / test) a la vez.
    """
    series = np.asarray(series).astype(float)
    T = len(series)
    if T < window_size + horizon:
        raise ValueError('Serie demasiado corta para el window_size y horizon dados.')

    X, y = [], []
    last_start = T - window_size - horizon + 1
    for start in range(0, last_start, stride):
        end = start + window_size
        target_end = end + horizon
        X.append(series[start:end])
        y.append(series[end:target_end])

    X = np.stack(X)
    y = np.stack(y)
    return X, y


def regression_metrics(y_true: np.ndarray, y_pred: np.ndarray) -> Dict[str, float]:
    y_true = np.asarray(y_true).reshape(-1)
    y_pred = np.asarray(y_pred).reshape(-1)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    eps = 1e-8
    mape = np.mean(np.abs((y_true - y_pred) / np.maximum(np.abs(y_true), eps))) * 100
    return {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}


def plot_time_series(dates, values, title: str = '', ylabel: str = ''):
    dates = pd.to_datetime(dates)
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=dates, y=values, mode='lines+markers', name='serie'))
    fig.update_layout(title=title, xaxis_title='Fecha', yaxis_title=ylabel, template='plotly_white')
    return fig


def plot_history_vs_pred(dates, y_true, y_pred, title: str = 'Histórico vs predicción'):
    dates = pd.to_datetime(dates)
    y_true = np.asarray(y_true).reshape(-1)
    y_pred = np.asarray(y_pred).reshape(-1)
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=dates, y=y_true, mode='lines', name='Real'))
    fig.add_trace(go.Scatter(x=dates, y=y_pred, mode='lines', name='Predicho', line=dict(dash='dash')))
    fig.update_layout(title=title, xaxis_title='Fecha', yaxis_title='Valor', template='plotly_white')
    return fig


def plot_future_forecast(history_dates, history_values, future_dates, future_preds, title: str = 'Pronóstico futuro'):
    history_dates = pd.to_datetime(history_dates)
    future_dates = pd.to_datetime(future_dates)
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=history_dates, y=history_values, mode='lines', name='Histórico'))
    fig.add_trace(go.Scatter(x=future_dates, y=future_preds, mode='lines+markers', name='Pronóstico', line=dict(dash='dash')))
    fig.update_layout(title=title, xaxis_title='Fecha', yaxis_title='Valor', template='plotly_white')
    return fig


def default_predict_fn(model, X):
    if hasattr(model, 'predict'):
        return model.predict(X)
    return model(X)


def recursive_forecast(model, last_window: np.ndarray, n_future: int, predict_fn=default_predict_fn) -> np.ndarray:
    """Pronóstico recursivo n_future pasos usando modelo one-step-ahead (en espacio escalado)."""
    window = np.asarray(last_window).reshape(1, -1)
    preds = []
    for _ in range(n_future):
        y_hat = predict_fn(model, window)
        y_hat = np.asarray(y_hat).reshape(-1)
        y_next = float(y_hat[0])
        preds.append(y_next)
        window = np.roll(window, -1, axis=1)
        window[0, -1] = y_next
    return np.array(preds)

def lstm_predict_fn(model, X_2d: np.ndarray):
    """
    X_2d: shape (batch, window_size)
    Lo convertimos a (batch, window_size, 1) para el LSTM.
    """
    X_2d = np.asarray(X_2d)
    X_3d = X_2d.reshape(X_2d.shape[0], X_2d.shape[1], 1)
    return model.predict(X_3d)

def transformer_predict_fn(model, X_2d: np.ndarray):
    """
    X_2d: shape (batch, window_size)
    Lo inflamos a (batch, window_size, 1) para el Transformer.
    """
    X_2d = np.asarray(X_2d)
    X_3d = X_2d.reshape(X_2d.shape[0], X_2d.shape[1], 1)
    return model.predict(X_3d)

print('Helpers cargados.')
# Out:
# Helpers cargados.

# %% [markdown]
# ## 3. Descarga de datos NWSS (CDC)

# %%
CDC_WASTEWATER_CSV_URL = 'https://data.cdc.gov/api/views/j9g8-acpt/rows.csv?accessType=DOWNLOAD'
CDC_WASTEWATER_FULL_CSV_PATH = LANDING_DIR / 'cdc_wastewater_sarscov2_full.csv'

def download_cdc_wastewater_full(url: str = CDC_WASTEWATER_CSV_URL,
                                 out_path: Path = CDC_WASTEWATER_FULL_CSV_PATH,
                                 use_cache: bool = True) -> Path:
    out_path = Path(out_path)
    if use_cache and out_path.exists():
        print(f'[INFO] Usando archivo en caché: {out_path}')
        return out_path
    print(f'[INFO] Descargando datos NWSS desde {url}')
    r = requests.get(url)
    r.raise_for_status()
    out_path.write_bytes(r.content)
    print(f'[OK] Guardado en {out_path}')
    return out_path

# download_cdc_wastewater_full()

# %% [markdown]
# ## 4. Carga y exploración rápida

# %%
df_raw = pd.read_csv(CDC_WASTEWATER_FULL_CSV_PATH)
print('Shape bruto:', df_raw.shape)
display(df_raw.head())
print(df_raw.columns.tolist())
# Out:
# C:\Users\esteb\AppData\Local\Temp\ipykernel_51192\4203612754.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv(CDC_WASTEWATER_FULL_CSV_PATH)
# Shape bruto: (504369, 35)
#    sewershed_id wwtp_jurisdiction county_fips counties_served  \
# 0           711                me       23019       Penobscot
# 1          1809                ri       44007      Providence
# 2           322                fl       12115        Sarasota
# 3           524                in       18113           Noble
# 4           694                me       23001    Androscoggin
#
#    population_served                         sample_id sample_collect_date  \
# 0               2500  000516f8c0f05102d4a010b987f62273          2023-11-28
# 1              10000  040ce1a855db659d046911c5d5758314          2023-07-05
# 2             100000  052760ee8f2bec3e7e4ac25f5bff23b4          2023-08-14
# 3              10000  0dd046c819c8214f02eb79056e57978a          2023-12-18
# 4              60000  0e08cd627f3702430558aaf38aefa6e4          2023-09-13
#
#                      sample_type      sample_matrix sample_location  ...  \
# 0  24-hr flow-weighted composite     raw wastewater            wwtp  ...
# 1  24-hr time-weighted composite     raw wastewater            wwtp  ...
# 2  24-hr flow-weighted composite  post grit removal            wwtp  ...
# 3  24-hr time-weighted composite     raw wastewater            wwtp  ...
# 4  24-hr flow-weighted composite     raw wastewater            wwtp  ...
#
#    pcr_target_flowpop_lin pcr_target_mic_lin       hum_frac_target_mic  \
# 0            3.634599e+08            0.02864  pepper mild mottle virus
# 1            4.267105e+07            0.00092  pepper mild mottle virus
# 2            1.263573e+08            0.00455  pepper mild mottle virus
# 3            5.170796e+07            0.00177        pmmov (gt-digital)
# 4            1.066697e+08            0.01578  pepper mild mottle virus
#
#   hum_frac_mic_conc    hum_frac_mic_unit rec_eff_percent rec_eff_target_name  \
# 0      1.002597e+07  copies/l wastewater        68.74511        brsv vaccine
# 1      1.772809e+08  copies/l wastewater        80.15343        brsv vaccine
# 2      1.163784e+08  copies/l wastewater        20.63618        brsv vaccine
# 3      4.752000e+07  copies/l wastewater        33.02887        bcov vaccine
# 4      1.410123e+07  copies/l wastewater         6.26729        brsv vaccine
#
#              rec_eff_spike_matrix rec_eff_spike_conc            date_updated
# 0  raw sample post pasteurization            5.34357  09/26/2025 10:40:00 AM
# 1  raw sample post pasteurization            5.00000  09/26/2025 10:40:00 AM
# 2  raw sample post pasteurization            5.34357  09/26/2025 10:40:00 AM
# 3                      raw sample            5.45000  09/26/2025 10:40:00 AM
# 4  raw sample post pasteurization            5.34357  09/26/2025 10:40:00 AM
#
# [5 rows x 35 columns]
# ['sewershed_id', 'wwtp_jurisdiction', 'county_fips', 'counties_served', 'population_served', 'sample_id', 'sample_collect_date', 'sample_type', 'sample_matrix', 'sample_location', 'flow_rate', 'concentration_method', 'pasteurized', 'pcr_type', 'extraction_method', 'major_lab_method', 'inhibition_detect', 'inhibition_adjust', 'ntc_amplify', 'pcr_target', 'pcr_gene_target_agg', 'pcr_target_avg_conc', 'pcr_target_units', 'lod_sewage', 'pcr_target_avg_conc_lin', 'pcr_target_flowpop_lin', 'pcr_target_mic_lin', 'hum_frac_target_mic', 'hum_frac_mic_conc', 'hum_frac_mic_unit', 'rec_eff_percent', 'rec_eff_target_name', 'rec_eff_spike_matrix', 'rec_eff_spike_conc', 'date_updated']

# %% [markdown]
# ## 5. Preprocesamiento base y construcción de una serie (ej. estado NY)
#
# Se elige un estado base (ej. NY) y se agrega la carga viral por fecha usando la mediana.

# %%
DATE_COL = 'sample_collect_date'
TARGET_COL = 'pcr_target_flowpop_lin'
STATE_COL = 'wwtp_jurisdiction'

df_raw[DATE_COL] = pd.to_datetime(df_raw[DATE_COL], errors='coerce')
df = df_raw.dropna(subset=[DATE_COL, TARGET_COL]).copy()

STATE = 'ny'  # puedes cambiar el estado base

df_state = df.query('wwtp_jurisdiction == @STATE')[[DATE_COL, TARGET_COL]].copy()
df_state = (
    df_state
    .groupby(DATE_COL, as_index=False)[TARGET_COL]
    .median()
    .sort_values(DATE_COL)
)
df_state = df_state.rename(columns={DATE_COL: 'date', TARGET_COL: 'target'})
df_state = df_state.dropna(subset=['date', 'target'])

print('Estado base:', STATE)
print('Rango de fechas:', df_state['date'].min(), '→', df_state['date'].max())
print('N observaciones:', len(df_state))
display(df_state.head())

fig = plot_time_series(df_state['date'], df_state['target'],
                       title=f'Serie – estado {STATE} (flow/pop)', ylabel='target')
fig.show()
# Out:
# Estado base: ny
# Rango de fechas: 2020-08-31 00:00:00 → 2025-09-17 00:00:00
# N observaciones: 1366
#         date        target
# 0 2020-08-31  2.832473e+06
# 1 2020-09-02  5.965088e+02
# 2 2020-09-04  2.355929e+04
# 3 2020-09-06  6.226106e+02
# 4 2020-09-08  5.880741e+06

# %% [markdown]
# ## 6. Split temporal + escalado (sin fuga de información)
#
# Primero se hace el split temporal sobre la serie cruda. Luego se ajusta el scaler con train y se aplica a val/test.

# %%
TRAIN_FRAC = 0.7
VAL_FRAC = 0.15
TEST_FRAC = 1.0 - TRAIN_FRAC - VAL_FRAC

SCALER_TYPE = 'minmax'  # minmax o standard

series = df_state.set_index('date')['target'].astype(float).sort_index()
n = len(series)
n_train = int(n * TRAIN_FRAC)
n_val = int(n * VAL_FRAC)
n_test = n - n_train - n_val

train_series = series.iloc[:n_train]
val_series   = series.iloc[n_train:n_train + n_val]
test_series  = series.iloc[n_train + n_val:]

print('Sizes → train:', len(train_series), 'val:', len(val_series), 'test:', len(test_series))

if SCALER_TYPE == 'minmax':
    scaler = MinMaxScaler()
elif SCALER_TYPE == 'standard':
    scaler = StandardScaler()
else:
    raise ValueError('SCALER_TYPE debe ser minmax o standard')

train_scaled = scaler.fit_transform(train_series.values.reshape(-1, 1)).reshape(-1)
val_scaled   = scaler.transform(val_series.values.reshape(-1, 1)).reshape(-1)
test_scaled  = scaler.transform(test_series.values.reshape(-1, 1)).reshape(-1)

print('Rango escalado train → min:', float(train_scaled.min()), 'max:', float(train_scaled.max()))
# Out:
# Sizes → train: 956 val: 204 test: 206
# Rango escalado train → min: 0.0 max: 0.9999999999999998

# %% [markdown]
# ## 7. Ventanas deslizantes por split (ya escalados)

# %%
WINDOW_SIZE = 60
HORIZON = 1

X_train, y_train = create_sliding_windows(train_scaled, WINDOW_SIZE, HORIZON)
X_val,   y_val   = create_sliding_windows(val_scaled,   WINDOW_SIZE, HORIZON)
X_test,  y_test  = create_sliding_windows(test_scaled,  WINDOW_SIZE, HORIZON)

print('X_train:', X_train.shape, 'y_train:', y_train.shape)
print('X_val  :', X_val.shape,   'y_val  :', y_val.shape)
print('X_test :', X_test.shape,  'y_test :', y_test.shape)

train_dates = train_series.index[WINDOW_SIZE:WINDOW_SIZE + len(y_train)]
val_dates   = val_series.index[WINDOW_SIZE:WINDOW_SIZE + len(y_val)]
test_dates  = test_series.index[WINDOW_SIZE:WINDOW_SIZE + len(y_test)]

print('Rango fechas train ventanas:', train_dates[0], '→', train_dates[-1])
print('Rango fechas test ventanas :', test_dates[0],  '→', test_dates[-1])
# Out:
# X_train: (896, 60) y_train: (896, 1)
# X_val  : (144, 60) y_val  : (144, 1)
# X_test : (146, 60) y_test : (146, 1)
# Rango fechas train ventanas: 2020-12-18 00:00:00 → 2024-05-15 00:00:00
# Rango fechas test ventanas : 2025-03-19 00:00:00 → 2025-09-17 00:00:00

# %% [markdown]
# ## 8. Modelo baseline ingenuo (último valor)

# %%
class NaiveLastValueModel:
    def fit(self, X, y=None):
        return self
    def predict(self, X):
        X = np.asarray(X)
        return X[:, -1:].copy()

baseline = NaiveLastValueModel().fit(X_train, y_train)

y_test_pred_baseline_scaled = baseline.predict(X_test).reshape(-1)
y_test_true_scaled = y_test.reshape(-1)

y_test_true = scaler.inverse_transform(y_test_true_scaled.reshape(-1, 1)).reshape(-1)
y_test_pred_baseline = scaler.inverse_transform(y_test_pred_baseline_scaled.reshape(-1, 1)).reshape(-1)

metrics_base = regression_metrics(y_test_true, y_test_pred_baseline)
print('Baseline – métricas test:', metrics_base)

fig = plot_history_vs_pred(test_dates, y_test_true, y_test_pred_baseline,
                           title='Baseline - Test vs predicción')
fig.show()
# Out:
# Baseline – métricas test: {'MAE': 9923368.411946509, 'RMSE': 23077818.468268175, 'MAPE': 266.37360870061053}

# %% [markdown]
# ## 9. Modelo LSTM

# %% [markdown]
# ### 9.1 Model

# %%
X_train_lstm = X_train.reshape(-1, WINDOW_SIZE, 1)
X_val_lstm   = X_val.reshape(-1, WINDOW_SIZE, 1)
X_test_lstm  = X_test.reshape(-1, WINDOW_SIZE, 1)

model_lstm = Sequential([
    LSTM(120, input_shape=(WINDOW_SIZE, 1), return_sequences=True),
    LSTM(60, input_shape=(WINDOW_SIZE, 1), return_sequences=True),
    LSTM(30, input_shape=(WINDOW_SIZE, 1), return_sequences=False),
    # Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(HORIZON),
])

model_lstm.compile(optimizer=Adam(learning_rate=1e-3), loss='mse', metrics=['mae'])
model_lstm.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 60, 120)           58560
#
#  lstm_5 (LSTM)               (None, 60, 60)            43440
#
#  lstm_6 (LSTM)               (None, 30)                10920
#
#  dense_4 (Dense)             (None, 32)                992
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 113,945
# Trainable params: 113,945
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 200
BATCH_SIZE = 64

history_lstm = model_lstm.fit(
    X_train_lstm,
    y_train,
    validation_data=(X_val_lstm, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
)
# Out:
# Epoch 1/200
# 14/14 [==============================] - 7s 193ms/step - loss: 0.0034 - mae: 0.0251 - val_loss: 2.1117e-04 - val_mae: 0.0090
# Epoch 2/200
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0032 - mae: 0.0221 - val_loss: 2.7651e-04 - val_mae: 0.0126
# Epoch 3/200
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0031 - mae: 0.0205 - val_loss: 2.1899e-04 - val_mae: 0.0074
# Epoch 4/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0031 - mae: 0.0202 - val_loss: 3.6383e-04 - val_mae: 0.0160
# Epoch 5/200
# 14/14 [==============================] - 2s 110ms/step - loss: 0.0031 - mae: 0.0216 - val_loss: 3.7997e-04 - val_mae: 0.0165
# Epoch 6/200
# 14/14 [==============================] - 2s 150ms/step - loss: 0.0031 - mae: 0.0201 - val_loss: 1.7070e-04 - val_mae: 0.0042
# Epoch 7/200
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0031 - mae: 0.0203 - val_loss: 2.6604e-04 - val_mae: 0.0121
# Epoch 8/200
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0031 - mae: 0.0210 - val_loss: 2.0248e-04 - val_mae: 0.0082
# Epoch 9/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0030 - mae: 0.0198 - val_loss: 3.9507e-04 - val_mae: 0.0168
# Epoch 10/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0031 - mae: 0.0205 - val_loss: 4.2808e-04 - val_mae: 0.0180
# Epoch 11/200
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0030 - mae: 0.0204 - val_loss: 1.8222e-04 - val_mae: 0.0055
# Epoch 12/200
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0030 - mae: 0.0188 - val_loss: 2.2164e-04 - val_mae: 0.0094
# Epoch 13/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0030 - mae: 0.0213 - val_loss: 3.6242e-04 - val_mae: 0.0158
# Epoch 14/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0031 - mae: 0.0213 - val_loss: 1.8490e-04 - val_mae: 0.0064
# Epoch 15/200
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0030 - mae: 0.0190 - val_loss: 1.8471e-04 - val_mae: 0.0048
# Epoch 16/200
# 14/14 [==============================] - 1s 91ms/step - loss: 0.0030 - mae: 0.0189 - val_loss: 2.3351e-04 - val_mae: 0.0102
# Epoch 17/200
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0029 - mae: 0.0196 - val_loss: 1.7544e-04 - val_mae: 0.0047
# Epoch 18/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0029 - mae: 0.0192 - val_loss: 1.9238e-04 - val_mae: 0.0065
# Epoch 19/200
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0030 - mae: 0.0209 - val_loss: 6.1169e-04 - val_mae: 0.0228
# Epoch 20/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0031 - mae: 0.0209 - val_loss: 4.2331e-04 - val_mae: 0.0179
# Epoch 21/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0029 - mae: 0.0193 - val_loss: 3.6418e-04 - val_mae: 0.0159
# Epoch 22/200
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0030 - mae: 0.0213 - val_loss: 2.5656e-04 - val_mae: 0.0094
# Epoch 23/200
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0030 - mae: 0.0206 - val_loss: 1.7395e-04 - val_mae: 0.0043
# Epoch 24/200
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0030 - mae: 0.0211 - val_loss: 3.7573e-04 - val_mae: 0.0141
# Epoch 25/200
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0031 - mae: 0.0213 - val_loss: 2.2664e-04 - val_mae: 0.0097
# Epoch 26/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0029 - mae: 0.0188 - val_loss: 1.7620e-04 - val_mae: 0.0050
# Epoch 27/200
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0031 - mae: 0.0224 - val_loss: 2.2696e-04 - val_mae: 0.0079
# Epoch 28/200
# 14/14 [==============================] - 2s 115ms/step - loss: 0.0031 - mae: 0.0211 - val_loss: 1.9268e-04 - val_mae: 0.0075
# Epoch 29/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0030 - mae: 0.0202 - val_loss: 1.7526e-04 - val_mae: 0.0054
# Epoch 30/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0029 - mae: 0.0198 - val_loss: 1.8169e-04 - val_mae: 0.0057
# Epoch 31/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0030 - mae: 0.0215 - val_loss: 3.0528e-04 - val_mae: 0.0137
# Epoch 32/200
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0030 - mae: 0.0211 - val_loss: 1.9943e-04 - val_mae: 0.0078
# Epoch 33/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0029 - mae: 0.0192 - val_loss: 2.1856e-04 - val_mae: 0.0093
# Epoch 34/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0029 - mae: 0.0192 - val_loss: 1.8167e-04 - val_mae: 0.0053
# Epoch 35/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0030 - mae: 0.0214 - val_loss: 2.9065e-04 - val_mae: 0.0109
# Epoch 36/200
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0030 - mae: 0.0213 - val_loss: 1.7766e-04 - val_mae: 0.0040
# Epoch 37/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0029 - mae: 0.0198 - val_loss: 1.7789e-04 - val_mae: 0.0050
# Epoch 38/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0029 - mae: 0.0195 - val_loss: 2.4604e-04 - val_mae: 0.0088
# Epoch 39/200
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0030 - mae: 0.0211 - val_loss: 1.7647e-04 - val_mae: 0.0042
# Epoch 40/200
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0029 - mae: 0.0202 - val_loss: 2.3579e-04 - val_mae: 0.0102
# Epoch 41/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0029 - mae: 0.0195 - val_loss: 2.2472e-04 - val_mae: 0.0093
# Epoch 42/200
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0029 - mae: 0.0206 - val_loss: 2.7096e-04 - val_mae: 0.0122
# Epoch 43/200
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0029 - mae: 0.0196 - val_loss: 2.9410e-04 - val_mae: 0.0131
# Epoch 44/200
# 14/14 [==============================] - 1s 76ms/step - loss: 0.0029 - mae: 0.0193 - val_loss: 2.5606e-04 - val_mae: 0.0113
# Epoch 45/200
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0030 - mae: 0.0218 - val_loss: 3.5319e-04 - val_mae: 0.0156
# Epoch 46/200
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0032 - mae: 0.0223 - val_loss: 4.7270e-04 - val_mae: 0.0194
# Epoch 47/200
# 14/14 [==============================] - 1s 70ms/step - loss: 0.0029 - mae: 0.0199 - val_loss: 1.7084e-04 - val_mae: 0.0041
# Epoch 48/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0030 - mae: 0.0211 - val_loss: 2.1669e-04 - val_mae: 0.0072
# Epoch 49/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0030 - mae: 0.0212 - val_loss: 2.2954e-04 - val_mae: 0.0080
# Epoch 50/200
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0029 - mae: 0.0197 - val_loss: 2.1383e-04 - val_mae: 0.0090
# Epoch 51/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0029 - mae: 0.0195 - val_loss: 2.8138e-04 - val_mae: 0.0126
# Epoch 52/200
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0029 - mae: 0.0215 - val_loss: 2.1283e-04 - val_mae: 0.0085
# Epoch 53/200
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0028 - mae: 0.0192 - val_loss: 2.3956e-04 - val_mae: 0.0105
# Epoch 54/200
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0029 - mae: 0.0203 - val_loss: 2.1388e-04 - val_mae: 0.0070
# Epoch 55/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0030 - mae: 0.0192 - val_loss: 2.8071e-04 - val_mae: 0.0126
# Epoch 56/200
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0029 - mae: 0.0203 - val_loss: 2.5697e-04 - val_mae: 0.0114
# Epoch 57/200
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0030 - mae: 0.0215 - val_loss: 1.8842e-04 - val_mae: 0.0060
# Epoch 58/200
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0030 - mae: 0.0215 - val_loss: 2.0354e-04 - val_mae: 0.0082
# Epoch 59/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0028 - mae: 0.0189 - val_loss: 1.8449e-04 - val_mae: 0.0061
# Epoch 60/200
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0028 - mae: 0.0193 - val_loss: 1.8011e-04 - val_mae: 0.0044
# Epoch 61/200
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0028 - mae: 0.0196 - val_loss: 2.9015e-04 - val_mae: 0.0130
# Epoch 62/200
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0029 - mae: 0.0203 - val_loss: 1.7890e-04 - val_mae: 0.0040
# Epoch 63/200
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0028 - mae: 0.0198 - val_loss: 2.5865e-04 - val_mae: 0.0095
# Epoch 64/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0029 - mae: 0.0211 - val_loss: 1.9756e-04 - val_mae: 0.0072
# Epoch 65/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0029 - mae: 0.0218 - val_loss: 2.6224e-04 - val_mae: 0.0118
# Epoch 66/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0030 - mae: 0.0197 - val_loss: 2.0448e-04 - val_mae: 0.0082
# Epoch 67/200
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0028 - mae: 0.0199 - val_loss: 2.5877e-04 - val_mae: 0.0114
# Epoch 68/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0030 - mae: 0.0205 - val_loss: 5.2028e-04 - val_mae: 0.0206
# Epoch 69/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0029 - mae: 0.0204 - val_loss: 1.9962e-04 - val_mae: 0.0078
# Epoch 70/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0030 - mae: 0.0216 - val_loss: 2.4052e-04 - val_mae: 0.0086
# Epoch 71/200
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0029 - mae: 0.0204 - val_loss: 2.9117e-04 - val_mae: 0.0132
# Epoch 72/200
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0029 - mae: 0.0195 - val_loss: 4.0113e-04 - val_mae: 0.0172
# Epoch 73/200
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0028 - mae: 0.0211 - val_loss: 2.5297e-04 - val_mae: 0.0092
# Epoch 74/200
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0029 - mae: 0.0214 - val_loss: 2.9078e-04 - val_mae: 0.0110
# Epoch 75/200
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0028 - mae: 0.0197 - val_loss: 1.7810e-04 - val_mae: 0.0056
# Epoch 76/200
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0028 - mae: 0.0197 - val_loss: 2.1518e-04 - val_mae: 0.0090
# Epoch 77/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0028 - mae: 0.0199 - val_loss: 2.2983e-04 - val_mae: 0.0098
# Epoch 78/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0029 - mae: 0.0188 - val_loss: 4.6168e-04 - val_mae: 0.0190
# Epoch 79/200
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0028 - mae: 0.0238 - val_loss: 5.7882e-04 - val_mae: 0.0220
# Epoch 80/200
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0029 - mae: 0.0208 - val_loss: 4.0583e-04 - val_mae: 0.0174
# Epoch 81/200
# 14/14 [==============================] - 1s 104ms/step - loss: 0.0029 - mae: 0.0233 - val_loss: 1.7796e-04 - val_mae: 0.0041
# Epoch 82/200
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0031 - mae: 0.0243 - val_loss: 2.4311e-04 - val_mae: 0.0088
# Epoch 83/200
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0029 - mae: 0.0201 - val_loss: 2.1178e-04 - val_mae: 0.0089
# Epoch 84/200
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0028 - mae: 0.0197 - val_loss: 3.8700e-04 - val_mae: 0.0167
# Epoch 85/200
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0027 - mae: 0.0194 - val_loss: 2.9997e-04 - val_mae: 0.0134
# Epoch 86/200
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0026 - mae: 0.0196 - val_loss: 1.7171e-04 - val_mae: 0.0044
# Epoch 87/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0027 - mae: 0.0196 - val_loss: 1.8233e-04 - val_mae: 0.0042
# Epoch 88/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0027 - mae: 0.0197 - val_loss: 2.1269e-04 - val_mae: 0.0065
# Epoch 89/200
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0028 - mae: 0.0230 - val_loss: 2.7220e-04 - val_mae: 0.0123
# Epoch 90/200
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0027 - mae: 0.0209 - val_loss: 3.3437e-04 - val_mae: 0.0150
# Epoch 91/200
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0029 - mae: 0.0201 - val_loss: 1.6778e-04 - val_mae: 0.0037
# Epoch 92/200
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0027 - mae: 0.0187 - val_loss: 1.7171e-04 - val_mae: 0.0035
# Epoch 93/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0027 - mae: 0.0204 - val_loss: 2.6115e-04 - val_mae: 0.0115
# Epoch 94/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0027 - mae: 0.0194 - val_loss: 4.5863e-04 - val_mae: 0.0189
# Epoch 95/200
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0029 - mae: 0.0245 - val_loss: 6.4320e-04 - val_mae: 0.0236
# Epoch 96/200
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0027 - mae: 0.0214 - val_loss: 3.1443e-04 - val_mae: 0.0142
# Epoch 97/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0027 - mae: 0.0210 - val_loss: 2.7946e-04 - val_mae: 0.0127
# Epoch 98/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0028 - mae: 0.0229 - val_loss: 4.0831e-04 - val_mae: 0.0151
# Epoch 99/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0027 - mae: 0.0226 - val_loss: 2.0358e-04 - val_mae: 0.0082
# Epoch 100/200
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0027 - mae: 0.0203 - val_loss: 1.7004e-04 - val_mae: 0.0036
# Epoch 101/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0026 - mae: 0.0198 - val_loss: 1.7018e-04 - val_mae: 0.0038
# Epoch 102/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0025 - mae: 0.0183 - val_loss: 2.4782e-04 - val_mae: 0.0111
# Epoch 103/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0027 - mae: 0.0206 - val_loss: 5.7807e-04 - val_mae: 0.0220
# Epoch 104/200
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0030 - mae: 0.0214 - val_loss: 3.6366e-04 - val_mae: 0.0160
# Epoch 105/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0030 - mae: 0.0209 - val_loss: 3.5572e-04 - val_mae: 0.0157
# Epoch 106/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0029 - mae: 0.0198 - val_loss: 1.9105e-04 - val_mae: 0.0050
# Epoch 107/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0026 - mae: 0.0193 - val_loss: 1.7833e-04 - val_mae: 0.0039
# Epoch 108/200
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0024 - mae: 0.0186 - val_loss: 1.8254e-04 - val_mae: 0.0047
# Epoch 109/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0024 - mae: 0.0192 - val_loss: 2.1561e-04 - val_mae: 0.0086
# Epoch 110/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0029 - mae: 0.0225 - val_loss: 3.5422e-04 - val_mae: 0.0156
# Epoch 111/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0031 - mae: 0.0199 - val_loss: 3.7866e-04 - val_mae: 0.0165
# Epoch 112/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0028 - mae: 0.0203 - val_loss: 2.3627e-04 - val_mae: 0.0106
# Epoch 113/200
# 14/14 [==============================] - 1s 91ms/step - loss: 0.0027 - mae: 0.0198 - val_loss: 2.1796e-04 - val_mae: 0.0094
# Epoch 114/200
# 14/14 [==============================] - 1s 103ms/step - loss: 0.0027 - mae: 0.0188 - val_loss: 1.7281e-04 - val_mae: 0.0051
# Epoch 115/200
# 14/14 [==============================] - 1s 91ms/step - loss: 0.0026 - mae: 0.0184 - val_loss: 1.7883e-04 - val_mae: 0.0059
# Epoch 116/200
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0025 - mae: 0.0200 - val_loss: 2.2983e-04 - val_mae: 0.0080
# Epoch 117/200
# 14/14 [==============================] - 4s 267ms/step - loss: 0.0027 - mae: 0.0220 - val_loss: 2.0226e-04 - val_mae: 0.0061
# Epoch 118/200
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0023 - mae: 0.0192 - val_loss: 3.2842e-04 - val_mae: 0.0147
# Epoch 119/200
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0027 - mae: 0.0191 - val_loss: 2.1209e-04 - val_mae: 0.0085
# Epoch 120/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0024 - mae: 0.0184 - val_loss: 3.4589e-04 - val_mae: 0.0151
# Epoch 121/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0025 - mae: 0.0209 - val_loss: 3.8067e-04 - val_mae: 0.0165
# Epoch 122/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0025 - mae: 0.0209 - val_loss: 2.0312e-04 - val_mae: 0.0081
# Epoch 123/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0024 - mae: 0.0184 - val_loss: 1.6900e-04 - val_mae: 0.0048
# Epoch 124/200
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0028 - mae: 0.0194 - val_loss: 2.6485e-04 - val_mae: 0.0115
# Epoch 125/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0026 - mae: 0.0200 - val_loss: 1.8292e-04 - val_mae: 0.0046
# Epoch 126/200
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0027 - mae: 0.0195 - val_loss: 2.6451e-04 - val_mae: 0.0115
# Epoch 127/200
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0025 - mae: 0.0194 - val_loss: 2.3424e-04 - val_mae: 0.0082
# Epoch 128/200
# 14/14 [==============================] - 2s 112ms/step - loss: 0.0023 - mae: 0.0190 - val_loss: 1.8405e-04 - val_mae: 0.0051
# Epoch 129/200
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0024 - mae: 0.0187 - val_loss: 2.0439e-04 - val_mae: 0.0062
# Epoch 130/200
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0022 - mae: 0.0187 - val_loss: 1.9054e-04 - val_mae: 0.0049
# Epoch 131/200
# 14/14 [==============================] - 1s 91ms/step - loss: 0.0023 - mae: 0.0190 - val_loss: 1.9442e-04 - val_mae: 0.0057
# Epoch 132/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0025 - mae: 0.0217 - val_loss: 2.7522e-04 - val_mae: 0.0120
# Epoch 133/200
# 14/14 [==============================] - 2s 108ms/step - loss: 0.0022 - mae: 0.0190 - val_loss: 3.7374e-04 - val_mae: 0.0163
# Epoch 134/200
# 14/14 [==============================] - 2s 110ms/step - loss: 0.0027 - mae: 0.0224 - val_loss: 3.5017e-04 - val_mae: 0.0155
# Epoch 135/200
# 14/14 [==============================] - 2s 120ms/step - loss: 0.0026 - mae: 0.0234 - val_loss: 5.4018e-04 - val_mae: 0.0208
# Epoch 136/200
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0024 - mae: 0.0199 - val_loss: 1.8426e-04 - val_mae: 0.0050
# Epoch 137/200
# 14/14 [==============================] - 2s 126ms/step - loss: 0.0024 - mae: 0.0187 - val_loss: 1.8433e-04 - val_mae: 0.0039
# Epoch 138/200
# 14/14 [==============================] - 2s 140ms/step - loss: 0.0020 - mae: 0.0177 - val_loss: 1.7799e-04 - val_mae: 0.0062
# Epoch 139/200
# 14/14 [==============================] - 2s 168ms/step - loss: 0.0024 - mae: 0.0198 - val_loss: 3.0697e-04 - val_mae: 0.0117
# Epoch 140/200
# 14/14 [==============================] - 2s 125ms/step - loss: 0.0023 - mae: 0.0187 - val_loss: 2.1642e-04 - val_mae: 0.0078
# Epoch 141/200
# 14/14 [==============================] - 2s 147ms/step - loss: 0.0021 - mae: 0.0190 - val_loss: 2.9465e-04 - val_mae: 0.0130
# Epoch 142/200
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0022 - mae: 0.0201 - val_loss: 2.0031e-04 - val_mae: 0.0056
# Epoch 143/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0021 - mae: 0.0197 - val_loss: 2.0036e-04 - val_mae: 0.0049
# Epoch 144/200
# 14/14 [==============================] - 2s 109ms/step - loss: 0.0029 - mae: 0.0236 - val_loss: 3.5840e-04 - val_mae: 0.0159
# Epoch 145/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0029 - mae: 0.0225 - val_loss: 2.3256e-04 - val_mae: 0.0094
# Epoch 146/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0026 - mae: 0.0191 - val_loss: 1.8902e-04 - val_mae: 0.0045
# Epoch 147/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0026 - mae: 0.0190 - val_loss: 2.1835e-04 - val_mae: 0.0068
# Epoch 148/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0023 - mae: 0.0186 - val_loss: 2.0977e-04 - val_mae: 0.0064
# Epoch 149/200
# 14/14 [==============================] - 2s 175ms/step - loss: 0.0023 - mae: 0.0193 - val_loss: 2.0729e-04 - val_mae: 0.0054
# Epoch 150/200
# 14/14 [==============================] - 2s 117ms/step - loss: 0.0020 - mae: 0.0186 - val_loss: 1.8405e-04 - val_mae: 0.0052
# Epoch 151/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0021 - mae: 0.0186 - val_loss: 1.7819e-04 - val_mae: 0.0055
# Epoch 152/200
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0020 - mae: 0.0188 - val_loss: 2.5448e-04 - val_mae: 0.0104
# Epoch 153/200
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0024 - mae: 0.0212 - val_loss: 2.6563e-04 - val_mae: 0.0107
# Epoch 154/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0022 - mae: 0.0190 - val_loss: 2.4189e-04 - val_mae: 0.0090
# Epoch 155/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0020 - mae: 0.0201 - val_loss: 3.8353e-04 - val_mae: 0.0161
# Epoch 156/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0021 - mae: 0.0211 - val_loss: 2.7320e-04 - val_mae: 0.0122
# Epoch 157/200
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0021 - mae: 0.0190 - val_loss: 2.1743e-04 - val_mae: 0.0081
# Epoch 158/200
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0020 - mae: 0.0186 - val_loss: 2.6892e-04 - val_mae: 0.0099
# Epoch 159/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0016 - mae: 0.0179 - val_loss: 2.1861e-04 - val_mae: 0.0076
# Epoch 160/200
# 14/14 [==============================] - 2s 109ms/step - loss: 0.0017 - mae: 0.0170 - val_loss: 1.8789e-04 - val_mae: 0.0049
# Epoch 161/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0016 - mae: 0.0173 - val_loss: 2.3289e-04 - val_mae: 0.0083
# Epoch 162/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0015 - mae: 0.0178 - val_loss: 1.9172e-04 - val_mae: 0.0074
# Epoch 163/200
# 14/14 [==============================] - 2s 110ms/step - loss: 0.0020 - mae: 0.0207 - val_loss: 1.8657e-04 - val_mae: 0.0063
# Epoch 164/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0019 - mae: 0.0195 - val_loss: 2.5540e-04 - val_mae: 0.0104
# Epoch 165/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0017 - mae: 0.0175 - val_loss: 2.7385e-04 - val_mae: 0.0117
# Epoch 166/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0016 - mae: 0.0176 - val_loss: 4.0990e-04 - val_mae: 0.0171
# Epoch 167/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0024 - mae: 0.0187 - val_loss: 1.9738e-04 - val_mae: 0.0074
# Epoch 168/200
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0025 - mae: 0.0185 - val_loss: 4.0126e-04 - val_mae: 0.0170
# Epoch 169/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0026 - mae: 0.0249 - val_loss: 3.1760e-04 - val_mae: 0.0122
# Epoch 170/200
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0020 - mae: 0.0193 - val_loss: 1.7956e-04 - val_mae: 0.0040
# Epoch 171/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0018 - mae: 0.0177 - val_loss: 1.7370e-04 - val_mae: 0.0039
# Epoch 172/200
# 14/14 [==============================] - 1s 104ms/step - loss: 0.0017 - mae: 0.0172 - val_loss: 1.9422e-04 - val_mae: 0.0054
# Epoch 173/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0016 - mae: 0.0179 - val_loss: 2.2289e-04 - val_mae: 0.0084
# Epoch 174/200
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0017 - mae: 0.0191 - val_loss: 2.3887e-04 - val_mae: 0.0095
# Epoch 175/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0018 - mae: 0.0179 - val_loss: 2.0203e-04 - val_mae: 0.0080
# Epoch 176/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0015 - mae: 0.0169 - val_loss: 1.8767e-04 - val_mae: 0.0060
# Epoch 177/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0015 - mae: 0.0167 - val_loss: 1.7811e-04 - val_mae: 0.0045
# Epoch 178/200
# 14/14 [==============================] - 1s 91ms/step - loss: 0.0019 - mae: 0.0183 - val_loss: 1.9201e-04 - val_mae: 0.0044
# Epoch 179/200
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0015 - mae: 0.0169 - val_loss: 2.0995e-04 - val_mae: 0.0065
# Epoch 180/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0017 - mae: 0.0165 - val_loss: 2.0208e-04 - val_mae: 0.0068
# Epoch 181/200
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0014 - mae: 0.0169 - val_loss: 2.0220e-04 - val_mae: 0.0052
# Epoch 182/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0022 - mae: 0.0188 - val_loss: 4.0725e-04 - val_mae: 0.0172
# Epoch 183/200
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0025 - mae: 0.0200 - val_loss: 2.4777e-04 - val_mae: 0.0106
# Epoch 184/200
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0018 - mae: 0.0170 - val_loss: 1.9261e-04 - val_mae: 0.0041
# Epoch 185/200
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0016 - mae: 0.0168 - val_loss: 2.2271e-04 - val_mae: 0.0080
# Epoch 186/200
# 14/14 [==============================] - 2s 107ms/step - loss: 0.0015 - mae: 0.0167 - val_loss: 3.3734e-04 - val_mae: 0.0145
# Epoch 187/200
# 14/14 [==============================] - 2s 113ms/step - loss: 0.0021 - mae: 0.0207 - val_loss: 4.4181e-04 - val_mae: 0.0185
# Epoch 188/200
# 14/14 [==============================] - 2s 147ms/step - loss: 0.0023 - mae: 0.0205 - val_loss: 2.2840e-04 - val_mae: 0.0095
# Epoch 189/200
# 14/14 [==============================] - 1s 105ms/step - loss: 0.0018 - mae: 0.0188 - val_loss: 1.9114e-04 - val_mae: 0.0062
# Epoch 190/200
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0016 - mae: 0.0183 - val_loss: 1.9553e-04 - val_mae: 0.0052
# Epoch 191/200
# 14/14 [==============================] - 2s 109ms/step - loss: 0.0014 - mae: 0.0159 - val_loss: 1.9474e-04 - val_mae: 0.0046
# Epoch 192/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0014 - mae: 0.0166 - val_loss: 2.0936e-04 - val_mae: 0.0067
# Epoch 193/200
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0015 - mae: 0.0174 - val_loss: 4.7112e-04 - val_mae: 0.0187
# Epoch 194/200
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0014 - mae: 0.0161 - val_loss: 2.0654e-04 - val_mae: 0.0079
# Epoch 195/200
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0014 - mae: 0.0168 - val_loss: 1.9504e-04 - val_mae: 0.0063
# Epoch 196/200
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0013 - mae: 0.0165 - val_loss: 1.9140e-04 - val_mae: 0.0056
# Epoch 197/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0012 - mae: 0.0153 - val_loss: 2.0010e-04 - val_mae: 0.0059
# Epoch 198/200
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0012 - mae: 0.0152 - val_loss: 2.2914e-04 - val_mae: 0.0078
# Epoch 199/200
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0012 - mae: 0.0157 - val_loss: 1.9290e-04 - val_mae: 0.0053
# Epoch 200/200
# 14/14 [==============================] - 1s 85ms/step - loss: 0.0013 - mae: 0.0156 - val_loss: 2.0423e-04 - val_mae: 0.0081

# %% [markdown]
# ### 9.2 Evaluación LSTM (métricas en escala original)

# %%
y_test_pred_lstm_scaled = model_lstm.predict(X_test_lstm).reshape(-1)
y_test_true_scaled = y_test.reshape(-1)

y_test_true_lstm = scaler.inverse_transform(y_test_true_scaled.reshape(-1, 1)).reshape(-1)
y_test_pred_lstm = scaler.inverse_transform(y_test_pred_lstm_scaled.reshape(-1, 1)).reshape(-1)

metrics_lstm = regression_metrics(y_test_true_lstm, y_test_pred_lstm)
print('LSTM – métricas test:', metrics_lstm)

fig = plot_history_vs_pred(test_dates, y_test_true_lstm, y_test_pred_lstm,
                           title='LSTM - Test vs predicción')
fig.show()
# Out:
# 5/5 [==============================] - 2s 41ms/step
# LSTM – métricas test: {'MAE': 8129185.361339042, 'RMSE': 16992274.299186885, 'MAPE': 371.1255186143688}

# %% [markdown]
# ### 9.3 Pronóstico futuro con LSTM

# %%
N_FUTURE = 30  # días de pronóstico

# Última ventana del split completo (test) ya escalado
last_window_scaled = test_scaled[-WINDOW_SIZE:]

# Usamos el predict_fn especial para LSTM
future_scaled = recursive_forecast(
    model_lstm,
    last_window_scaled,
    N_FUTURE,
    predict_fn=lstm_predict_fn,  # 👈 aquí la magia
)

# Volvemos a escala original
future_preds = scaler.inverse_transform(future_scaled.reshape(-1, 1)).reshape(-1)

last_date = series.index[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1),
                             periods=N_FUTURE, freq='D')

fig = plot_future_forecast(
    series.index,
    series.values,
    future_dates,
    future_preds,
    title=f'Pronóstico LSTM {N_FUTURE} días – estado {STATE}',
)
fig.show()
# Out:
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step

# %% [markdown]
# ## 12. Modelos Transformer

# %%
# Datos en formato (batch, timesteps, features) para el Transformer
X_train_tf = X_train.reshape(-1, WINDOW_SIZE, 1)
X_val_tf   = X_val.reshape(-1, WINDOW_SIZE, 1)
X_test_tf  = X_test.reshape(-1, WINDOW_SIZE, 1)

# Definición directa del modelo Transformer
inputs_tf = Input(shape=(WINDOW_SIZE, 1), name="transformer_input")

# Proyección inicial a d_model = 64
x = Dense(64, name="proj_input")(inputs_tf)

# === BLOQUE TRANSFORMER 1 (self-attention + feed-forward) ===

# Self-attention (4 cabezas, key_dim=64)
attn1 = MultiHeadAttention(
    num_heads=4,
    key_dim=64,
    name="mha_1"
)(x, x)
attn1 = Dropout(0.1, name="drop_attn_1")(attn1)

# Residual + norm
out1 = LayerNormalization(epsilon=1e-6, name="ln_attn_1")(x + attn1)

# Feed-forward interno
ff1 = Dense(128, activation="relu", name="ffn1_1")(out1)
ff1 = Dropout(0.1, name="drop_ffn_1")(ff1)
ff1 = Dense(64, name="ffn1_2")(ff1)

# Residual + norm
x = LayerNormalization(epsilon=1e-6, name="ln_ffn_1")(out1 + ff1)

# === FIN BLOQUE TRANSFORMER ===
# Si quieres 2 bloques, literal copias/pegas este bloque cambiando los nombres.

# Pooling temporal
x = GlobalAveragePooling1D(name="gap")(x)

# Capas densas de salida
x = Dense(32, activation="relu", name="dense_out")(x)
outputs_tf = Dense(HORIZON, name="output")(x)

model_tf = Model(inputs=inputs_tf, outputs=outputs_tf, name="ts_transformer_simple")

model_tf.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss="mse",
    metrics=["mae"],
)

model_tf.summary()
# Out:
# Model: "ts_transformer_simple"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  transformer_input (InputLayer)  [(None, 60, 1)]     0           []
#
#  proj_input (Dense)             (None, 60, 64)       128         ['transformer_input[0][0]']
#
#  mha_1 (MultiHeadAttention)     (None, 60, 64)       66368       ['proj_input[0][0]',
#                                                                   'proj_input[0][0]']
#
#  drop_attn_1 (Dropout)          (None, 60, 64)       0           ['mha_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 60, 64)      0           ['proj_input[0][0]',
#  mbda)                                                            'drop_attn_1[0][0]']
#
#  ln_attn_1 (LayerNormalization)  (None, 60, 64)      128         ['tf.__operators__.add_2[0][0]']
#
#  ffn1_1 (Dense)                 (None, 60, 128)      8320        ['ln_attn_1[0][0]']
#
#  drop_ffn_1 (Dropout)           (None, 60, 128)      0           ['ffn1_1[0][0]']
#
#  ffn1_2 (Dense)                 (None, 60, 64)       8256        ['drop_ffn_1[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 60, 64)      0           ['ln_attn_1[0][0]',
#  mbda)                                                            'ffn1_2[0][0]']
#
#  ln_ffn_1 (LayerNormalization)  (None, 60, 64)       128         ['tf.__operators__.add_3[0][0]']
#
#  gap (GlobalAveragePooling1D)   (None, 64)           0           ['ln_ffn_1[0][0]']
#
#  dense_out (Dense)              (None, 32)           2080        ['gap[0][0]']
#
#  output (Dense)                 (None, 1)            33          ['dense_out[0][0]']
#
# ==================================================================================================
# Total params: 85,441
# Trainable params: 85,441
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history_tf = model_tf.fit(
    X_train_tf,
    y_train,
    validation_data=(X_val_tf, y_val),
    epochs=40,
    batch_size=32,
    verbose=1,
)
# Out:
# Epoch 1/40
# 28/28 [==============================] - 2s 33ms/step - loss: 0.3473 - mae: 0.3109 - val_loss: 2.3857e-04 - val_mae: 0.0087
# Epoch 2/40
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0053 - mae: 0.0475 - val_loss: 3.8741e-04 - val_mae: 0.0150
# Epoch 3/40
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0037 - mae: 0.0302 - val_loss: 4.8723e-04 - val_mae: 0.0198
# Epoch 4/40
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0037 - mae: 0.0270 - val_loss: 2.9764e-04 - val_mae: 0.0136
# Epoch 5/40
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0036 - mae: 0.0268 - val_loss: 2.8174e-04 - val_mae: 0.0108
# Epoch 6/40
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0037 - mae: 0.0273 - val_loss: 1.6950e-04 - val_mae: 0.0031
# Epoch 7/40
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0035 - mae: 0.0249 - val_loss: 8.8482e-04 - val_mae: 0.0285
# Epoch 8/40
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0036 - mae: 0.0259 - val_loss: 6.3065e-04 - val_mae: 0.0233
# Epoch 9/40
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0036 - mae: 0.0274 - val_loss: 1.6689e-04 - val_mae: 0.0038
# Epoch 10/40
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0035 - mae: 0.0248 - val_loss: 4.7010e-04 - val_mae: 0.0193
# Epoch 11/40
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0036 - mae: 0.0260 - val_loss: 2.4743e-04 - val_mae: 0.0111
# Epoch 12/40
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0036 - mae: 0.0273 - val_loss: 2.1354e-04 - val_mae: 0.0068
# Epoch 13/40
# 28/28 [==============================] - 1s 28ms/step - loss: 0.0037 - mae: 0.0275 - val_loss: 2.2847e-04 - val_mae: 0.0100
# Epoch 14/40
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0036 - mae: 0.0268 - val_loss: 1.8502e-04 - val_mae: 0.0046
# Epoch 15/40
# 28/28 [==============================] - 1s 53ms/step - loss: 0.0035 - mae: 0.0245 - val_loss: 2.9830e-04 - val_mae: 0.0115
# Epoch 16/40
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0035 - mae: 0.0258 - val_loss: 2.0684e-04 - val_mae: 0.0063
# Epoch 17/40
# 28/28 [==============================] - 1s 32ms/step - loss: 0.0036 - mae: 0.0265 - val_loss: 1.7206e-04 - val_mae: 0.0032
# Epoch 18/40
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0035 - mae: 0.0253 - val_loss: 2.1592e-04 - val_mae: 0.0091
# Epoch 19/40
# 28/28 [==============================] - 1s 28ms/step - loss: 0.0036 - mae: 0.0266 - val_loss: 1.9355e-04 - val_mae: 0.0074
# Epoch 20/40
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0036 - mae: 0.0262 - val_loss: 2.4291e-04 - val_mae: 0.0108
# Epoch 21/40
# 28/28 [==============================] - 1s 31ms/step - loss: 0.0035 - mae: 0.0261 - val_loss: 2.7112e-04 - val_mae: 0.0101
# Epoch 22/40
# 28/28 [==============================] - 1s 26ms/step - loss: 0.0037 - mae: 0.0281 - val_loss: 2.6908e-04 - val_mae: 0.0100
# Epoch 23/40
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0036 - mae: 0.0262 - val_loss: 3.4750e-04 - val_mae: 0.0134
# Epoch 24/40
# 28/28 [==============================] - 1s 50ms/step - loss: 0.0035 - mae: 0.0260 - val_loss: 2.1721e-04 - val_mae: 0.0092
# Epoch 25/40
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0038 - mae: 0.0285 - val_loss: 3.3514e-04 - val_mae: 0.0129
# Epoch 26/40
# 28/28 [==============================] - 1s 54ms/step - loss: 0.0041 - mae: 0.0339 - val_loss: 2.2776e-04 - val_mae: 0.0078
# Epoch 27/40
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0035 - mae: 0.0239 - val_loss: 5.5547e-04 - val_mae: 0.0215
# Epoch 28/40
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0036 - mae: 0.0263 - val_loss: 1.8025e-04 - val_mae: 0.0040
# Epoch 29/40
# 28/28 [==============================] - 1s 30ms/step - loss: 0.0039 - mae: 0.0291 - val_loss: 5.5352e-04 - val_mae: 0.0214
# Epoch 30/40
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0041 - mae: 0.0340 - val_loss: 7.3917e-04 - val_mae: 0.0256
# Epoch 31/40
# 28/28 [==============================] - 1s 52ms/step - loss: 0.0036 - mae: 0.0276 - val_loss: 4.6545e-04 - val_mae: 0.0191
# Epoch 32/40
# 28/28 [==============================] - 1s 29ms/step - loss: 0.0039 - mae: 0.0306 - val_loss: 3.3208e-04 - val_mae: 0.0148
# Epoch 33/40
# 28/28 [==============================] - 1s 33ms/step - loss: 0.0035 - mae: 0.0254 - val_loss: 2.2314e-04 - val_mae: 0.0074
# Epoch 34/40
# 28/28 [==============================] - 1s 35ms/step - loss: 0.0036 - mae: 0.0269 - val_loss: 2.0028e-04 - val_mae: 0.0080
# Epoch 35/40
# 28/28 [==============================] - 1s 29ms/step - loss: 0.0039 - mae: 0.0298 - val_loss: 1.9333e-04 - val_mae: 0.0052
# Epoch 36/40
# 28/28 [==============================] - 1s 30ms/step - loss: 0.0037 - mae: 0.0268 - val_loss: 0.0011 - val_mae: 0.0313
# Epoch 37/40
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0039 - mae: 0.0324 - val_loss: 5.0315e-04 - val_mae: 0.0183
# Epoch 38/40
# 28/28 [==============================] - 1s 41ms/step - loss: 0.0035 - mae: 0.0262 - val_loss: 1.8910e-04 - val_mae: 0.0069
# Epoch 39/40
# 28/28 [==============================] - 1s 32ms/step - loss: 0.0036 - mae: 0.0281 - val_loss: 4.9007e-04 - val_mae: 0.0198
# Epoch 40/40
# 28/28 [==============================] - 1s 33ms/step - loss: 0.0035 - mae: 0.0266 - val_loss: 1.8902e-04 - val_mae: 0.0069

# %% [markdown]
# ## 13. Evaluación Transformer

# %%
# Predicciones en ESCALA ESCALADA
y_test_pred_tf_scaled = model_tf.predict(X_test_tf).reshape(-1)
y_test_true_scaled    = y_test.reshape(-1)

# Volver a escala original
y_test_true_tf = scaler.inverse_transform(
    y_test_true_scaled.reshape(-1, 1)
).reshape(-1)

y_test_pred_tf = scaler.inverse_transform(
    y_test_pred_tf_scaled.reshape(-1, 1)
).reshape(-1)

metrics_tf = regression_metrics(y_test_true_tf, y_test_pred_tf)
print("Transformer – métricas test:", metrics_tf)

fig = plot_history_vs_pred(
    test_dates,
    y_test_true_tf,
    y_test_pred_tf,
    title="Transformer – Test vs predicción",
)
fig.show()
# Out:
# 5/5 [==============================] - 0s 12ms/step
# Transformer – métricas test: {'MAE': 9069529.000200136, 'RMSE': 17005337.216128398, 'MAPE': 334.88196064358624}

# %% [markdown]
# ## 14. Pronostico Futuro

# %%
N_FUTURE_TF = 30  # días de pronóstico con Transformer

last_window_scaled_tf = test_scaled[-WINDOW_SIZE:]

future_scaled_tf = recursive_forecast(
    model_tf,
    last_window_scaled_tf,
    N_FUTURE_TF,
    predict_fn=transformer_predict_fn,
)

future_preds_tf = scaler.inverse_transform(
    future_scaled_tf.reshape(-1, 1)
).reshape(-1)

last_date = series.index[-1]
future_dates_tf = pd.date_range(
    start=last_date + pd.Timedelta(days=1),
    periods=N_FUTURE_TF,
    freq="D",
)

fig = plot_future_forecast(
    series.index,
    series.values,
    future_dates_tf,
    future_preds_tf,
    title=f"Pronóstico Transformer {N_FUTURE_TF} días – estado {STATE}",
)
fig.show()
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step

# %% [markdown]
# ## 15. Conclusiones y hallazgos
#
# Deja este bloque para redactar al final del examen:
# - Comportamiento de la serie del estado base.
# - Comparación baseline vs LSTM.
# - Limitaciones del enfoque.
# - Cómo se podría extender de forma robusta a un modelo multi-estado.
