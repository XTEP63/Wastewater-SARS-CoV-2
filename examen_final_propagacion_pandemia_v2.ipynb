# %% [markdown]
# # Examen Final: Pronóstico de propagación de pandemia en EE.UU. usando modelos de series de tiempo
#
# ## Objetivo
#
# Este notebook tiene como objetivo predecir la **propagación de la pandemia de COVID-19** en los estados de EE.UU., basándose en los datos de carga viral en aguas residuales. Usaremos modelos de series de tiempo como **LSTM** y **Transformer** para hacer predicciones sobre la evolución futura de la pandemia, con un enfoque de propagación entre estados utilizando una **matriz de adyacencia**.
#
# ### Fase 1: Definición del problema
# 1. **Predicción por Estado:** Entrenaremos un modelo generalizado usando datos de un estado (inicialmente Nueva York) y lo aplicaremos a todos los estados.
# 2. **Umbral de Riesgo:** Definiremos un umbral para identificar qué estados están en riesgo de entrar en una pandemia.
# 3. **Propagación a Estados Adyacentes:** Usaremos una matriz de adyacencia para simular cómo los estados vecinos influencian la propagación del virus.
# 4. **Modelo de Propagación Ajustado:** Entrenaremos el modelo ajustado para incluir el efecto de la proximidad geográfica entre los estados.
#
# ### Fase 2: Implementación técnica
# 1. Descargaremos los datos de **CDC Wastewater** utilizando la API del **National Wastewater Surveillance System (NWSS)**.
# 2. Limpieza y exploración de los datos, convirtiéndolos en una serie de tiempo adecuada para entrenamiento.
# 3. Entrenamiento de los modelos **LSTM** y **Transformer** para hacer predicciones de la carga viral.
# 4. Evaluación del rendimiento del modelo usando **MAE, RMSE y MAPE**.
# 5. Pronóstico para los próximos **30 días** y propagación entre estados adyacentes.
#
# Notebook plantilla con estructura lista para:
# - Construir serie de carga viral en aguas residuales (CDC NWSS).
# - Hacer split temporal train/val/test sin fuga.
# - Escalar solo con train y aplicar a val/test.
# - Crear ventanas deslizantes por split.
# - Entrenar LSTM, comparar vs baseline y hacer pronóstico futuro.
# - Extender a propagación entre estados con matriz de adyacencia (TODO).

# %% [markdown]
# ## 1. Imports, configuración de paths y seeds

# %%
import os
import random
from pathlib import Path
from typing import Tuple, Dict, List

import numpy as np
import pandas as pd
import plotly.graph_objects as go
import requests

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam    
from tensorflow.keras.layers import (
    Input,
    MultiHeadAttention,
    LayerNormalization,
    GlobalAveragePooling1D,
    Dense,
    Dropout,
)
from tensorflow.keras import Model
import tensorflow as tf
from tensorflow.keras.layers import Embedding, Lambda

# Paths base
PROJECT_ROOT = Path('.')
DATA_DIR = PROJECT_ROOT / 'data'
LANDING_DIR = DATA_DIR / 'landing'
PROCESSED_DIR = DATA_DIR / 'processed'
FIGURES_DIR = PROJECT_ROOT / 'figures'
MODELS_DIR = PROJECT_ROOT / 'models'

for d in (DATA_DIR, LANDING_DIR, PROCESSED_DIR, FIGURES_DIR, MODELS_DIR):
    d.mkdir(parents=True, exist_ok=True)

# Seed global
GLOBAL_SEED = 42

def set_global_seed(seed: int = 42):
    global GLOBAL_SEED
    GLOBAL_SEED = seed
    random.seed(seed)
    np.random.seed(seed)

set_global_seed(GLOBAL_SEED)
print(f'Seed global fijada en {GLOBAL_SEED}')
print('PROJECT_ROOT:', PROJECT_ROOT.resolve())
# Out:
# Seed global fijada en 42
# PROJECT_ROOT: C:\Users\esteb\apps\Wastewater-SARS-CoV-2

# %% [markdown]
# ## 2. Helpers: ventanas, métricas, gráficas y forecasting

# %%
def create_sliding_windows(
    series: np.ndarray,
    window_size: int,
    horizon: int = 1,
    stride: int = 1,
) -> Tuple[np.ndarray, np.ndarray]:
    """Crea ventanas deslizantes sobre una serie ya escalada o cruda.
    Se asume que se usa con un split (train / val / test) a la vez.
    """
    series = np.asarray(series).astype(float)
    T = len(series)
    if T < window_size + horizon:
        raise ValueError('Serie demasiado corta para el window_size y horizon dados.')

    X, y = [], []
    last_start = T - window_size - horizon + 1
    for start in range(0, last_start, stride):
        end = start + window_size
        target_end = end + horizon
        X.append(series[start:end])
        y.append(series[end:target_end])

    X = np.stack(X)
    y = np.stack(y)
    return X, y


def regression_metrics(y_true: np.ndarray, y_pred: np.ndarray) -> Dict[str, float]:
    y_true = np.asarray(y_true).reshape(-1)
    y_pred = np.asarray(y_pred).reshape(-1)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    eps = 1e-8
    mape = np.mean(np.abs((y_true - y_pred) / np.maximum(np.abs(y_true), eps))) * 100
    return {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}


def plot_time_series(dates, values, title: str = '', ylabel: str = ''):
    dates = pd.to_datetime(dates)
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=dates, y=values, mode='lines+markers', name='serie'))
    fig.update_layout(title=title, xaxis_title='Fecha', yaxis_title=ylabel, template='plotly_white')
    return fig


def plot_history_vs_pred(dates, y_true, y_pred, title: str = 'Histórico vs predicción'):
    dates = pd.to_datetime(dates)
    y_true = np.asarray(y_true).reshape(-1)
    y_pred = np.asarray(y_pred).reshape(-1)
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=dates, y=y_true, mode='lines', name='Real'))
    fig.add_trace(go.Scatter(x=dates, y=y_pred, mode='lines', name='Predicho', line=dict(dash='dash')))
    fig.update_layout(title=title, xaxis_title='Fecha', yaxis_title='Valor', template='plotly_white')
    return fig


def plot_future_forecast(history_dates, history_values, future_dates, future_preds, title: str = 'Pronóstico futuro'):
    history_dates = pd.to_datetime(history_dates)
    future_dates = pd.to_datetime(future_dates)
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=history_dates, y=history_values, mode='lines', name='Histórico'))
    fig.add_trace(go.Scatter(x=future_dates, y=future_preds, mode='lines+markers', name='Pronóstico', line=dict(dash='dash')))
    fig.update_layout(title=title, xaxis_title='Fecha', yaxis_title='Valor', template='plotly_white')
    return fig


def default_predict_fn(model, X):
    if hasattr(model, 'predict'):
        return model.predict(X)
    return model(X)


def recursive_forecast(model, last_window: np.ndarray, n_future: int, predict_fn=default_predict_fn) -> np.ndarray:
    """Pronóstico recursivo n_future pasos usando modelo one-step-ahead (en espacio escalado)."""
    window = np.asarray(last_window).reshape(1, -1)
    preds = []
    for _ in range(n_future):
        y_hat = predict_fn(model, window)
        y_hat = np.asarray(y_hat).reshape(-1)
        y_next = float(y_hat[0])
        preds.append(y_next)
        window = np.roll(window, -1, axis=1)
        window[0, -1] = y_next
    return np.array(preds)

def lstm_predict_fn(model, X_2d: np.ndarray):
    """
    X_2d: shape (batch, window_size)
    Lo convertimos a (batch, window_size, 1) para el LSTM.
    """
    X_2d = np.asarray(X_2d)
    X_3d = X_2d.reshape(X_2d.shape[0], X_2d.shape[1], 1)
    return model.predict(X_3d)

def transformer_predict_fn(model, X_2d: np.ndarray):
    """
    X_2d: shape (batch, window_size)
    Lo inflamos a (batch, window_size, 1) para el Transformer.
    """
    X_2d = np.asarray(X_2d)
    X_3d = X_2d.reshape(X_2d.shape[0], X_2d.shape[1], 1)
    return model.predict(X_3d)

def get_sinusoidal_positional_encoding(max_len: int, d_model: int) -> np.ndarray:
    """
    Positional encoding tipo 'Attention is All You Need'.

    Devuelve un array de shape (1, max_len, d_model) listo para sumarse a (batch, T, d_model).
    """
    positions = np.arange(max_len)[:, np.newaxis]          # (T, 1)
    dims = np.arange(d_model)[np.newaxis, :]               # (1, D)

    angle_rates = 1.0 / np.power(10000, (2 * (dims // 2)) / d_model)
    angle_rads = positions * angle_rates                   # (T, D)

    pe = np.zeros_like(angle_rads)
    # índices pares → senos
    pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
    # índices impares → cosenos
    pe[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pe = pe[np.newaxis, ...]  # (1, T, D)
    return pe.astype("float32")

print('Helpers cargados.')
# Out:
# Helpers cargados.

# %% [markdown]
# ## 3. Descarga de datos NWSS (CDC)

# %%
CDC_WASTEWATER_CSV_URL = 'https://data.cdc.gov/api/views/j9g8-acpt/rows.csv?accessType=DOWNLOAD'
CDC_WASTEWATER_FULL_CSV_PATH = LANDING_DIR / 'cdc_wastewater_sarscov2_full.csv'

def download_cdc_wastewater_full(url: str = CDC_WASTEWATER_CSV_URL,
                                 out_path: Path = CDC_WASTEWATER_FULL_CSV_PATH,
                                 use_cache: bool = True) -> Path:
    out_path = Path(out_path)
    if use_cache and out_path.exists():
        print(f'[INFO] Usando archivo en caché: {out_path}')
        return out_path
    print(f'[INFO] Descargando datos NWSS desde {url}')
    r = requests.get(url)
    r.raise_for_status()
    out_path.write_bytes(r.content)
    print(f'[OK] Guardado en {out_path}')
    return out_path

# download_cdc_wastewater_full()

# %% [markdown]
# ## 4. Carga y exploración rápida

# %%
df_raw = pd.read_csv(CDC_WASTEWATER_FULL_CSV_PATH)
print('Shape bruto:', df_raw.shape)
display(df_raw.head())
print(df_raw.columns.tolist())
# Out:
# C:\Users\esteb\AppData\Local\Temp\ipykernel_51192\4203612754.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_raw = pd.read_csv(CDC_WASTEWATER_FULL_CSV_PATH)
# Shape bruto: (504369, 35)
#    sewershed_id wwtp_jurisdiction county_fips counties_served  \
# 0           711                me       23019       Penobscot
# 1          1809                ri       44007      Providence
# 2           322                fl       12115        Sarasota
# 3           524                in       18113           Noble
# 4           694                me       23001    Androscoggin
#
#    population_served                         sample_id sample_collect_date  \
# 0               2500  000516f8c0f05102d4a010b987f62273          2023-11-28
# 1              10000  040ce1a855db659d046911c5d5758314          2023-07-05
# 2             100000  052760ee8f2bec3e7e4ac25f5bff23b4          2023-08-14
# 3              10000  0dd046c819c8214f02eb79056e57978a          2023-12-18
# 4              60000  0e08cd627f3702430558aaf38aefa6e4          2023-09-13
#
#                      sample_type      sample_matrix sample_location  ...  \
# 0  24-hr flow-weighted composite     raw wastewater            wwtp  ...
# 1  24-hr time-weighted composite     raw wastewater            wwtp  ...
# 2  24-hr flow-weighted composite  post grit removal            wwtp  ...
# 3  24-hr time-weighted composite     raw wastewater            wwtp  ...
# 4  24-hr flow-weighted composite     raw wastewater            wwtp  ...
#
#    pcr_target_flowpop_lin pcr_target_mic_lin       hum_frac_target_mic  \
# 0            3.634599e+08            0.02864  pepper mild mottle virus
# 1            4.267105e+07            0.00092  pepper mild mottle virus
# 2            1.263573e+08            0.00455  pepper mild mottle virus
# 3            5.170796e+07            0.00177        pmmov (gt-digital)
# 4            1.066697e+08            0.01578  pepper mild mottle virus
#
#   hum_frac_mic_conc    hum_frac_mic_unit rec_eff_percent rec_eff_target_name  \
# 0      1.002597e+07  copies/l wastewater        68.74511        brsv vaccine
# 1      1.772809e+08  copies/l wastewater        80.15343        brsv vaccine
# 2      1.163784e+08  copies/l wastewater        20.63618        brsv vaccine
# 3      4.752000e+07  copies/l wastewater        33.02887        bcov vaccine
# 4      1.410123e+07  copies/l wastewater         6.26729        brsv vaccine
#
#              rec_eff_spike_matrix rec_eff_spike_conc            date_updated
# 0  raw sample post pasteurization            5.34357  09/26/2025 10:40:00 AM
# 1  raw sample post pasteurization            5.00000  09/26/2025 10:40:00 AM
# 2  raw sample post pasteurization            5.34357  09/26/2025 10:40:00 AM
# 3                      raw sample            5.45000  09/26/2025 10:40:00 AM
# 4  raw sample post pasteurization            5.34357  09/26/2025 10:40:00 AM
#
# [5 rows x 35 columns]
# ['sewershed_id', 'wwtp_jurisdiction', 'county_fips', 'counties_served', 'population_served', 'sample_id', 'sample_collect_date', 'sample_type', 'sample_matrix', 'sample_location', 'flow_rate', 'concentration_method', 'pasteurized', 'pcr_type', 'extraction_method', 'major_lab_method', 'inhibition_detect', 'inhibition_adjust', 'ntc_amplify', 'pcr_target', 'pcr_gene_target_agg', 'pcr_target_avg_conc', 'pcr_target_units', 'lod_sewage', 'pcr_target_avg_conc_lin', 'pcr_target_flowpop_lin', 'pcr_target_mic_lin', 'hum_frac_target_mic', 'hum_frac_mic_conc', 'hum_frac_mic_unit', 'rec_eff_percent', 'rec_eff_target_name', 'rec_eff_spike_matrix', 'rec_eff_spike_conc', 'date_updated']

# %% [markdown]
# ## 5. Preprocesamiento base y construcción de una serie (ej. estado NY)
#
# Se elige un estado base (ej. NY) y se agrega la carga viral por fecha usando la mediana.

# %%
DATE_COL = 'sample_collect_date'
TARGET_COL = 'pcr_target_flowpop_lin'
STATE_COL = 'wwtp_jurisdiction'

df_raw[DATE_COL] = pd.to_datetime(df_raw[DATE_COL], errors='coerce')
df = df_raw.dropna(subset=[DATE_COL, TARGET_COL]).copy()

STATE = 'ny'  # puedes cambiar el estado base

df_state = df.query('wwtp_jurisdiction == @STATE')[[DATE_COL, TARGET_COL]].copy()
df_state = (
    df_state
    .groupby(DATE_COL, as_index=False)[TARGET_COL]
    .median()
    .sort_values(DATE_COL)
)
df_state = df_state.rename(columns={DATE_COL: 'date', TARGET_COL: 'target'})
df_state = df_state.dropna(subset=['date', 'target'])

print('Estado base:', STATE)
print('Rango de fechas:', df_state['date'].min(), '→', df_state['date'].max())
print('N observaciones:', len(df_state))
display(df_state.head())

fig = plot_time_series(df_state['date'], df_state['target'],
                       title=f'Serie – estado {STATE} (flow/pop)', ylabel='target')
fig.show()
# Out:
# Estado base: ny
# Rango de fechas: 2020-08-31 00:00:00 → 2025-09-17 00:00:00
# N observaciones: 1366
#         date        target
# 0 2020-08-31  2.832473e+06
# 1 2020-09-02  5.965088e+02
# 2 2020-09-04  2.355929e+04
# 3 2020-09-06  6.226106e+02
# 4 2020-09-08  5.880741e+06

# %% [markdown]
# ## 6. Split temporal + escalado (sin fuga de información)
#
# Primero se hace el split temporal sobre la serie cruda. Luego se ajusta el scaler con train y se aplica a val/test.

# %%
TRAIN_FRAC = 0.7
VAL_FRAC = 0.15
TEST_FRAC = 1.0 - TRAIN_FRAC - VAL_FRAC

SCALER_TYPE = 'minmax'  # minmax o standard

series = df_state.set_index('date')['target'].astype(float).sort_index()
n = len(series)
n_train = int(n * TRAIN_FRAC)
n_val = int(n * VAL_FRAC)
n_test = n - n_train - n_val

train_series = series.iloc[:n_train]
val_series   = series.iloc[n_train:n_train + n_val]
test_series  = series.iloc[n_train + n_val:]

print('Sizes → train:', len(train_series), 'val:', len(val_series), 'test:', len(test_series))

if SCALER_TYPE == 'minmax':
    scaler = MinMaxScaler()
elif SCALER_TYPE == 'standard':
    scaler = StandardScaler()
else:
    raise ValueError('SCALER_TYPE debe ser minmax o standard')

train_scaled = scaler.fit_transform(train_series.values.reshape(-1, 1)).reshape(-1)
val_scaled   = scaler.transform(val_series.values.reshape(-1, 1)).reshape(-1)
test_scaled  = scaler.transform(test_series.values.reshape(-1, 1)).reshape(-1)

print('Rango escalado train → min:', float(train_scaled.min()), 'max:', float(train_scaled.max()))
# Out:
# Sizes → train: 956 val: 204 test: 206
# Rango escalado train → min: 0.0 max: 0.9999999999999998

# %% [markdown]
# ## 7. Ventanas deslizantes por split (ya escalados)

# %%
WINDOW_SIZE = 7
HORIZON = 1

X_train, y_train = create_sliding_windows(train_scaled, WINDOW_SIZE, HORIZON)
X_val,   y_val   = create_sliding_windows(val_scaled,   WINDOW_SIZE, HORIZON)
X_test,  y_test  = create_sliding_windows(test_scaled,  WINDOW_SIZE, HORIZON)

print('X_train:', X_train.shape, 'y_train:', y_train.shape)
print('X_val  :', X_val.shape,   'y_val  :', y_val.shape)
print('X_test :', X_test.shape,  'y_test :', y_test.shape)

train_dates = train_series.index[WINDOW_SIZE:WINDOW_SIZE + len(y_train)]
val_dates   = val_series.index[WINDOW_SIZE:WINDOW_SIZE + len(y_val)]
test_dates  = test_series.index[WINDOW_SIZE:WINDOW_SIZE + len(y_test)]

print('Rango fechas train ventanas:', train_dates[0], '→', train_dates[-1])
print('Rango fechas test ventanas :', test_dates[0],  '→', test_dates[-1])
# Out:
# X_train: (949, 7) y_train: (949, 1)
# X_val  : (197, 7) y_val  : (197, 1)
# X_test : (199, 7) y_test : (199, 1)
# Rango fechas train ventanas: 2020-09-13 00:00:00 → 2024-05-15 00:00:00
# Rango fechas test ventanas : 2025-01-15 00:00:00 → 2025-09-17 00:00:00

# %% [markdown]
# ## 8. Modelo baseline ingenuo (último valor)

# %%
class NaiveLastValueModel:
    def fit(self, X, y=None):
        return self
    def predict(self, X):
        X = np.asarray(X)
        return X[:, -1:].copy()

baseline = NaiveLastValueModel().fit(X_train, y_train)

y_test_pred_baseline_scaled = baseline.predict(X_test).reshape(-1)
y_test_true_scaled = y_test.reshape(-1)

y_test_true = scaler.inverse_transform(y_test_true_scaled.reshape(-1, 1)).reshape(-1)
y_test_pred_baseline = scaler.inverse_transform(y_test_pred_baseline_scaled.reshape(-1, 1)).reshape(-1)

metrics_base = regression_metrics(y_test_true, y_test_pred_baseline)
print('Baseline – métricas test:', metrics_base)

fig = plot_history_vs_pred(test_dates, y_test_true, y_test_pred_baseline,
                           title='Baseline - Test vs predicción')
fig.show()
# Out:
# Baseline – métricas test: {'MAE': 8566050.49316392, 'RMSE': 20151293.6795827, 'MAPE': 319.5636773371569}

# %% [markdown]
# ## 9. Modelo LSTM

# %% [markdown]
# ### 9.1 Model

# %%
X_train_lstm = X_train.reshape(-1, WINDOW_SIZE, 1)
X_val_lstm   = X_val.reshape(-1, WINDOW_SIZE, 1)
X_test_lstm  = X_test.reshape(-1, WINDOW_SIZE, 1)

model_lstm = Sequential([
    LSTM(120, input_shape=(WINDOW_SIZE, 1), return_sequences=True),
    LSTM(60, input_shape=(WINDOW_SIZE, 1), return_sequences=True),
    LSTM(30, input_shape=(WINDOW_SIZE, 1), return_sequences=False),
    # Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(HORIZON),
])

model_lstm.compile(optimizer=Adam(learning_rate=1e-3), loss='mse', metrics=['mae'])
model_lstm.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 7, 120)            58560
#
#  lstm_8 (LSTM)               (None, 7, 60)             43440
#
#  lstm_9 (LSTM)               (None, 30)                10920
#
#  dense_6 (Dense)             (None, 32)                992
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 113,945
# Trainable params: 113,945
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 200
BATCH_SIZE = 64

history_lstm = model_lstm.fit(
    X_train_lstm,
    y_train,
    validation_data=(X_val_lstm, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
)
# Out:
# Epoch 1/200
# 15/15 [==============================] - 7s 99ms/step - loss: 0.0032 - mae: 0.0222 - val_loss: 5.7704e-04 - val_mae: 0.0173
# Epoch 2/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0030 - mae: 0.0209 - val_loss: 4.1297e-04 - val_mae: 0.0054
# Epoch 3/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0030 - mae: 0.0190 - val_loss: 7.2364e-04 - val_mae: 0.0215
# Epoch 4/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0030 - mae: 0.0209 - val_loss: 4.1621e-04 - val_mae: 0.0048
# Epoch 5/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0029 - mae: 0.0185 - val_loss: 8.8409e-04 - val_mae: 0.0251
# Epoch 6/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0029 - mae: 0.0203 - val_loss: 4.1384e-04 - val_mae: 0.0064
# Epoch 7/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0029 - mae: 0.0200 - val_loss: 4.0481e-04 - val_mae: 0.0060
# Epoch 8/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0030 - mae: 0.0191 - val_loss: 4.2452e-04 - val_mae: 0.0080
# Epoch 9/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0029 - mae: 0.0194 - val_loss: 4.1100e-04 - val_mae: 0.0069
# Epoch 10/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0029 - mae: 0.0195 - val_loss: 6.4151e-04 - val_mae: 0.0189
# Epoch 11/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0030 - mae: 0.0216 - val_loss: 4.2561e-04 - val_mae: 0.0081
# Epoch 12/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0029 - mae: 0.0197 - val_loss: 5.1698e-04 - val_mae: 0.0144
# Epoch 13/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0029 - mae: 0.0189 - val_loss: 6.3083e-04 - val_mae: 0.0182
# Epoch 14/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0029 - mae: 0.0198 - val_loss: 7.9545e-04 - val_mae: 0.0231
# Epoch 15/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0030 - mae: 0.0208 - val_loss: 8.8629e-04 - val_mae: 0.0254
# Epoch 16/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0030 - mae: 0.0220 - val_loss: 5.9056e-04 - val_mae: 0.0176
# Epoch 17/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0030 - mae: 0.0208 - val_loss: 4.9062e-04 - val_mae: 0.0127
# Epoch 18/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0029 - mae: 0.0194 - val_loss: 4.5818e-04 - val_mae: 0.0111
# Epoch 19/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0029 - mae: 0.0187 - val_loss: 4.2592e-04 - val_mae: 0.0073
# Epoch 20/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0029 - mae: 0.0197 - val_loss: 4.4002e-04 - val_mae: 0.0070
# Epoch 21/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0030 - mae: 0.0204 - val_loss: 3.9689e-04 - val_mae: 0.0064
# Epoch 22/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0029 - mae: 0.0203 - val_loss: 4.3821e-04 - val_mae: 0.0099
# Epoch 23/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0029 - mae: 0.0194 - val_loss: 7.0242e-04 - val_mae: 0.0205
# Epoch 24/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0029 - mae: 0.0197 - val_loss: 5.4179e-04 - val_mae: 0.0148
# Epoch 25/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0029 - mae: 0.0194 - val_loss: 5.6548e-04 - val_mae: 0.0152
# Epoch 26/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0029 - mae: 0.0199 - val_loss: 4.0434e-04 - val_mae: 0.0057
# Epoch 27/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0030 - mae: 0.0207 - val_loss: 4.1778e-04 - val_mae: 0.0086
# Epoch 28/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0029 - mae: 0.0205 - val_loss: 4.1563e-04 - val_mae: 0.0056
# Epoch 29/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0029 - mae: 0.0186 - val_loss: 5.1788e-04 - val_mae: 0.0137
# Epoch 30/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0028 - mae: 0.0187 - val_loss: 4.2705e-04 - val_mae: 0.0066
# Epoch 31/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0028 - mae: 0.0191 - val_loss: 4.2014e-04 - val_mae: 0.0055
# Epoch 32/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0028 - mae: 0.0194 - val_loss: 4.3484e-04 - val_mae: 0.0074
# Epoch 33/200
# 15/15 [==============================] - 1s 36ms/step - loss: 0.0028 - mae: 0.0190 - val_loss: 4.6280e-04 - val_mae: 0.0096
# Epoch 34/200
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0029 - mae: 0.0202 - val_loss: 4.3762e-04 - val_mae: 0.0067
# Epoch 35/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0028 - mae: 0.0184 - val_loss: 4.3935e-04 - val_mae: 0.0084
# Epoch 36/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0028 - mae: 0.0187 - val_loss: 5.5115e-04 - val_mae: 0.0149
# Epoch 37/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0028 - mae: 0.0183 - val_loss: 4.9231e-04 - val_mae: 0.0108
# Epoch 38/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0028 - mae: 0.0189 - val_loss: 4.9622e-04 - val_mae: 0.0118
# Epoch 39/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0028 - mae: 0.0183 - val_loss: 4.7230e-04 - val_mae: 0.0108
# Epoch 40/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0028 - mae: 0.0196 - val_loss: 4.3565e-04 - val_mae: 0.0058
# Epoch 41/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0028 - mae: 0.0203 - val_loss: 4.2351e-04 - val_mae: 0.0063
# Epoch 42/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0029 - mae: 0.0197 - val_loss: 5.2167e-04 - val_mae: 0.0135
# Epoch 43/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0028 - mae: 0.0190 - val_loss: 4.9042e-04 - val_mae: 0.0115
# Epoch 44/200
# 15/15 [==============================] - 0s 34ms/step - loss: 0.0028 - mae: 0.0185 - val_loss: 4.9033e-04 - val_mae: 0.0109
# Epoch 45/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0027 - mae: 0.0189 - val_loss: 4.3963e-04 - val_mae: 0.0059
# Epoch 46/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0028 - mae: 0.0186 - val_loss: 5.1466e-04 - val_mae: 0.0130
# Epoch 47/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0028 - mae: 0.0189 - val_loss: 4.5509e-04 - val_mae: 0.0068
# Epoch 48/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0028 - mae: 0.0184 - val_loss: 4.3494e-04 - val_mae: 0.0068
# Epoch 49/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0028 - mae: 0.0192 - val_loss: 4.8315e-04 - val_mae: 0.0079
# Epoch 50/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0027 - mae: 0.0183 - val_loss: 4.6133e-04 - val_mae: 0.0082
# Epoch 51/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0027 - mae: 0.0196 - val_loss: 4.7393e-04 - val_mae: 0.0068
# Epoch 52/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0027 - mae: 0.0196 - val_loss: 4.4383e-04 - val_mae: 0.0061
# Epoch 53/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0028 - mae: 0.0187 - val_loss: 5.0552e-04 - val_mae: 0.0118
# Epoch 54/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0027 - mae: 0.0184 - val_loss: 4.8073e-04 - val_mae: 0.0084
# Epoch 55/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0028 - mae: 0.0181 - val_loss: 6.0077e-04 - val_mae: 0.0166
# Epoch 56/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0027 - mae: 0.0201 - val_loss: 4.5574e-04 - val_mae: 0.0067
# Epoch 57/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0028 - mae: 0.0190 - val_loss: 4.8307e-04 - val_mae: 0.0105
# Epoch 58/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0028 - mae: 0.0202 - val_loss: 4.6340e-04 - val_mae: 0.0054
# Epoch 59/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0027 - mae: 0.0201 - val_loss: 4.8255e-04 - val_mae: 0.0100
# Epoch 60/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0028 - mae: 0.0187 - val_loss: 5.3284e-04 - val_mae: 0.0135
# Epoch 61/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0028 - mae: 0.0195 - val_loss: 5.1328e-04 - val_mae: 0.0118
# Epoch 62/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0027 - mae: 0.0189 - val_loss: 4.7799e-04 - val_mae: 0.0071
# Epoch 63/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0027 - mae: 0.0185 - val_loss: 4.7191e-04 - val_mae: 0.0059
# Epoch 64/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0028 - mae: 0.0188 - val_loss: 4.5217e-04 - val_mae: 0.0064
# Epoch 65/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0027 - mae: 0.0184 - val_loss: 4.9769e-04 - val_mae: 0.0069
# Epoch 66/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0028 - mae: 0.0188 - val_loss: 4.5938e-04 - val_mae: 0.0064
# Epoch 67/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0027 - mae: 0.0193 - val_loss: 4.5956e-04 - val_mae: 0.0063
# Epoch 68/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0027 - mae: 0.0184 - val_loss: 5.8741e-04 - val_mae: 0.0152
# Epoch 69/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0027 - mae: 0.0196 - val_loss: 4.8039e-04 - val_mae: 0.0065
# Epoch 70/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0027 - mae: 0.0193 - val_loss: 4.8903e-04 - val_mae: 0.0059
# Epoch 71/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0027 - mae: 0.0195 - val_loss: 4.9191e-04 - val_mae: 0.0090
# Epoch 72/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0026 - mae: 0.0183 - val_loss: 5.3582e-04 - val_mae: 0.0124
# Epoch 73/200
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0027 - mae: 0.0188 - val_loss: 5.2779e-04 - val_mae: 0.0091
# Epoch 74/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0026 - mae: 0.0196 - val_loss: 5.3725e-04 - val_mae: 0.0088
# Epoch 75/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0027 - mae: 0.0204 - val_loss: 5.3789e-04 - val_mae: 0.0116
# Epoch 76/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0026 - mae: 0.0189 - val_loss: 4.9499e-04 - val_mae: 0.0067
# Epoch 77/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0026 - mae: 0.0179 - val_loss: 5.0327e-04 - val_mae: 0.0073
# Epoch 78/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0026 - mae: 0.0183 - val_loss: 5.3276e-04 - val_mae: 0.0103
# Epoch 79/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0026 - mae: 0.0191 - val_loss: 5.3315e-04 - val_mae: 0.0121
# Epoch 80/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0026 - mae: 0.0185 - val_loss: 5.6781e-04 - val_mae: 0.0129
# Epoch 81/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0027 - mae: 0.0189 - val_loss: 6.0220e-04 - val_mae: 0.0112
# Epoch 82/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0027 - mae: 0.0221 - val_loss: 4.9199e-04 - val_mae: 0.0074
# Epoch 83/200
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0028 - mae: 0.0199 - val_loss: 5.2616e-04 - val_mae: 0.0076
# Epoch 84/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0026 - mae: 0.0211 - val_loss: 5.3652e-04 - val_mae: 0.0094
# Epoch 85/200
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0026 - mae: 0.0193 - val_loss: 4.9334e-04 - val_mae: 0.0063
# Epoch 86/200
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0025 - mae: 0.0182 - val_loss: 4.7004e-04 - val_mae: 0.0056
# Epoch 87/200
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0025 - mae: 0.0186 - val_loss: 4.9516e-04 - val_mae: 0.0075
# Epoch 88/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0025 - mae: 0.0190 - val_loss: 4.9148e-04 - val_mae: 0.0093
# Epoch 89/200
# 15/15 [==============================] - 3s 181ms/step - loss: 0.0027 - mae: 0.0203 - val_loss: 6.9782e-04 - val_mae: 0.0188
# Epoch 90/200
# 15/15 [==============================] - 3s 194ms/step - loss: 0.0027 - mae: 0.0188 - val_loss: 4.9334e-04 - val_mae: 0.0078
# Epoch 91/200
# 15/15 [==============================] - 3s 191ms/step - loss: 0.0026 - mae: 0.0201 - val_loss: 5.2986e-04 - val_mae: 0.0079
# Epoch 92/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0026 - mae: 0.0203 - val_loss: 6.8035e-04 - val_mae: 0.0181
# Epoch 93/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0026 - mae: 0.0201 - val_loss: 5.6218e-04 - val_mae: 0.0142
# Epoch 94/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0026 - mae: 0.0202 - val_loss: 5.1292e-04 - val_mae: 0.0061
# Epoch 95/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0025 - mae: 0.0191 - val_loss: 5.4765e-04 - val_mae: 0.0072
# Epoch 96/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0025 - mae: 0.0178 - val_loss: 5.5199e-04 - val_mae: 0.0083
# Epoch 97/200
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0024 - mae: 0.0184 - val_loss: 5.0090e-04 - val_mae: 0.0061
# Epoch 98/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0025 - mae: 0.0182 - val_loss: 5.0934e-04 - val_mae: 0.0107
# Epoch 99/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0025 - mae: 0.0199 - val_loss: 5.9446e-04 - val_mae: 0.0103
# Epoch 100/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0026 - mae: 0.0211 - val_loss: 5.7839e-04 - val_mae: 0.0088
# Epoch 101/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0024 - mae: 0.0187 - val_loss: 5.0147e-04 - val_mae: 0.0071
# Epoch 102/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0024 - mae: 0.0182 - val_loss: 5.4092e-04 - val_mae: 0.0061
# Epoch 103/200
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0024 - mae: 0.0180 - val_loss: 5.2367e-04 - val_mae: 0.0071
# Epoch 104/200
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0024 - mae: 0.0190 - val_loss: 6.2407e-04 - val_mae: 0.0145
# Epoch 105/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0024 - mae: 0.0182 - val_loss: 5.3738e-04 - val_mae: 0.0113
# Epoch 106/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0023 - mae: 0.0182 - val_loss: 5.3458e-04 - val_mae: 0.0074
# Epoch 107/200
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0024 - mae: 0.0184 - val_loss: 6.2561e-04 - val_mae: 0.0153
# Epoch 108/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0024 - mae: 0.0191 - val_loss: 5.7830e-04 - val_mae: 0.0069
# Epoch 109/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0025 - mae: 0.0200 - val_loss: 5.8549e-04 - val_mae: 0.0091
# Epoch 110/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0025 - mae: 0.0186 - val_loss: 5.6052e-04 - val_mae: 0.0062
# Epoch 111/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0028 - mae: 0.0207 - val_loss: 5.5455e-04 - val_mae: 0.0081
# Epoch 112/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0027 - mae: 0.0189 - val_loss: 5.7901e-04 - val_mae: 0.0120
# Epoch 113/200
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0026 - mae: 0.0193 - val_loss: 5.4781e-04 - val_mae: 0.0066
# Epoch 114/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0024 - mae: 0.0189 - val_loss: 5.9923e-04 - val_mae: 0.0077
# Epoch 115/200
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0024 - mae: 0.0186 - val_loss: 5.7930e-04 - val_mae: 0.0101
# Epoch 116/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0023 - mae: 0.0184 - val_loss: 5.7698e-04 - val_mae: 0.0114
# Epoch 117/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0024 - mae: 0.0205 - val_loss: 5.0547e-04 - val_mae: 0.0096
# Epoch 118/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0023 - mae: 0.0186 - val_loss: 5.6398e-04 - val_mae: 0.0064
# Epoch 119/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0026 - mae: 0.0174 - val_loss: 5.8067e-04 - val_mae: 0.0066
# Epoch 120/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0024 - mae: 0.0193 - val_loss: 6.2977e-04 - val_mae: 0.0146
# Epoch 121/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0024 - mae: 0.0192 - val_loss: 5.3679e-04 - val_mae: 0.0087
# Epoch 122/200
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0022 - mae: 0.0173 - val_loss: 5.1535e-04 - val_mae: 0.0067
# Epoch 123/200
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0023 - mae: 0.0172 - val_loss: 5.8629e-04 - val_mae: 0.0125
# Epoch 124/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0025 - mae: 0.0210 - val_loss: 6.6834e-04 - val_mae: 0.0121
# Epoch 125/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0026 - mae: 0.0195 - val_loss: 5.3660e-04 - val_mae: 0.0075
# Epoch 126/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0024 - mae: 0.0177 - val_loss: 6.3281e-04 - val_mae: 0.0097
# Epoch 127/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0023 - mae: 0.0175 - val_loss: 6.1415e-04 - val_mae: 0.0093
# Epoch 128/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0023 - mae: 0.0188 - val_loss: 5.6988e-04 - val_mae: 0.0076
# Epoch 129/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0023 - mae: 0.0189 - val_loss: 5.8654e-04 - val_mae: 0.0072
# Epoch 130/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0024 - mae: 0.0179 - val_loss: 5.4668e-04 - val_mae: 0.0094
# Epoch 131/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0023 - mae: 0.0178 - val_loss: 6.1387e-04 - val_mae: 0.0089
# Epoch 132/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0023 - mae: 0.0175 - val_loss: 6.2836e-04 - val_mae: 0.0093
# Epoch 133/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0022 - mae: 0.0179 - val_loss: 5.7301e-04 - val_mae: 0.0068
# Epoch 134/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0022 - mae: 0.0175 - val_loss: 5.8353e-04 - val_mae: 0.0065
# Epoch 135/200
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0022 - mae: 0.0179 - val_loss: 5.7555e-04 - val_mae: 0.0127
# Epoch 136/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0023 - mae: 0.0188 - val_loss: 6.5634e-04 - val_mae: 0.0078
# Epoch 137/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0022 - mae: 0.0174 - val_loss: 5.9798e-04 - val_mae: 0.0075
# Epoch 138/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0021 - mae: 0.0166 - val_loss: 5.2312e-04 - val_mae: 0.0061
# Epoch 139/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0021 - mae: 0.0177 - val_loss: 6.5050e-04 - val_mae: 0.0133
# Epoch 140/200
# 15/15 [==============================] - 1s 48ms/step - loss: 0.0022 - mae: 0.0188 - val_loss: 5.8621e-04 - val_mae: 0.0101
# Epoch 141/200
# 15/15 [==============================] - 1s 76ms/step - loss: 0.0022 - mae: 0.0180 - val_loss: 5.3539e-04 - val_mae: 0.0092
# Epoch 142/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0022 - mae: 0.0173 - val_loss: 6.0687e-04 - val_mae: 0.0105
# Epoch 143/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0023 - mae: 0.0178 - val_loss: 6.9672e-04 - val_mae: 0.0118
# Epoch 144/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0022 - mae: 0.0193 - val_loss: 7.8388e-04 - val_mae: 0.0100
# Epoch 145/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0023 - mae: 0.0178 - val_loss: 6.2378e-04 - val_mae: 0.0126
# Epoch 146/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0022 - mae: 0.0179 - val_loss: 5.5033e-04 - val_mae: 0.0078
# Epoch 147/200
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0021 - mae: 0.0171 - val_loss: 8.1680e-04 - val_mae: 0.0160
# Epoch 148/200
# 15/15 [==============================] - 1s 38ms/step - loss: 0.0021 - mae: 0.0177 - val_loss: 6.0572e-04 - val_mae: 0.0072
# Epoch 149/200
# 15/15 [==============================] - 1s 37ms/step - loss: 0.0022 - mae: 0.0192 - val_loss: 7.8689e-04 - val_mae: 0.0131
# Epoch 150/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0021 - mae: 0.0192 - val_loss: 5.6732e-04 - val_mae: 0.0079
# Epoch 151/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0022 - mae: 0.0171 - val_loss: 8.0517e-04 - val_mae: 0.0091
# Epoch 152/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0022 - mae: 0.0183 - val_loss: 7.4397e-04 - val_mae: 0.0086
# Epoch 153/200
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0021 - mae: 0.0188 - val_loss: 7.9090e-04 - val_mae: 0.0072
# Epoch 154/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0023 - mae: 0.0196 - val_loss: 7.0225e-04 - val_mae: 0.0113
# Epoch 155/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0022 - mae: 0.0187 - val_loss: 8.2819e-04 - val_mae: 0.0083
# Epoch 156/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0022 - mae: 0.0177 - val_loss: 7.1195e-04 - val_mae: 0.0146
# Epoch 157/200
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0021 - mae: 0.0196 - val_loss: 7.7185e-04 - val_mae: 0.0129
# Epoch 158/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0021 - mae: 0.0188 - val_loss: 6.3275e-04 - val_mae: 0.0122
# Epoch 159/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0021 - mae: 0.0179 - val_loss: 7.3826e-04 - val_mae: 0.0059
# Epoch 160/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0022 - mae: 0.0178 - val_loss: 7.2360e-04 - val_mae: 0.0088
# Epoch 161/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0020 - mae: 0.0178 - val_loss: 7.9919e-04 - val_mae: 0.0126
# Epoch 162/200
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0022 - mae: 0.0199 - val_loss: 7.3806e-04 - val_mae: 0.0199
# Epoch 163/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0023 - mae: 0.0191 - val_loss: 7.3129e-04 - val_mae: 0.0086
# Epoch 164/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0021 - mae: 0.0186 - val_loss: 7.3047e-04 - val_mae: 0.0063
# Epoch 165/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0020 - mae: 0.0169 - val_loss: 5.6873e-04 - val_mae: 0.0133
# Epoch 166/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0021 - mae: 0.0182 - val_loss: 0.0010 - val_mae: 0.0112
# Epoch 167/200
# 15/15 [==============================] - 1s 45ms/step - loss: 0.0022 - mae: 0.0178 - val_loss: 6.9052e-04 - val_mae: 0.0082
# Epoch 168/200
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0021 - mae: 0.0176 - val_loss: 7.4579e-04 - val_mae: 0.0140
# Epoch 169/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0021 - mae: 0.0182 - val_loss: 6.6675e-04 - val_mae: 0.0158
# Epoch 170/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0021 - mae: 0.0182 - val_loss: 9.6411e-04 - val_mae: 0.0074
# Epoch 171/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0020 - mae: 0.0167 - val_loss: 6.7145e-04 - val_mae: 0.0088
# Epoch 172/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0019 - mae: 0.0166 - val_loss: 6.0627e-04 - val_mae: 0.0073
# Epoch 173/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0018 - mae: 0.0163 - val_loss: 8.0574e-04 - val_mae: 0.0100
# Epoch 174/200
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0018 - mae: 0.0167 - val_loss: 7.0906e-04 - val_mae: 0.0169
# Epoch 175/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0019 - mae: 0.0181 - val_loss: 7.0447e-04 - val_mae: 0.0127
# Epoch 176/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0019 - mae: 0.0167 - val_loss: 5.6083e-04 - val_mae: 0.0126
# Epoch 177/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0020 - mae: 0.0178 - val_loss: 0.0014 - val_mae: 0.0097
# Epoch 178/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0023 - mae: 0.0193 - val_loss: 7.2409e-04 - val_mae: 0.0107
# Epoch 179/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0021 - mae: 0.0194 - val_loss: 0.0013 - val_mae: 0.0117
# Epoch 180/200
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0020 - mae: 0.0176 - val_loss: 6.0303e-04 - val_mae: 0.0055
# Epoch 181/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0022 - mae: 0.0180 - val_loss: 0.0012 - val_mae: 0.0090
# Epoch 182/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0023 - mae: 0.0189 - val_loss: 0.0011 - val_mae: 0.0073
# Epoch 183/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0020 - mae: 0.0174 - val_loss: 0.0012 - val_mae: 0.0083
# Epoch 184/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0020 - mae: 0.0163 - val_loss: 8.4539e-04 - val_mae: 0.0140
# Epoch 185/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0020 - mae: 0.0179 - val_loss: 0.0011 - val_mae: 0.0118
# Epoch 186/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0022 - mae: 0.0176 - val_loss: 9.5980e-04 - val_mae: 0.0097
# Epoch 187/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0017 - mae: 0.0172 - val_loss: 0.0010 - val_mae: 0.0094
# Epoch 188/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0020 - mae: 0.0193 - val_loss: 0.0010 - val_mae: 0.0118
# Epoch 189/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0018 - mae: 0.0169 - val_loss: 9.1340e-04 - val_mae: 0.0078
# Epoch 190/200
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0017 - mae: 0.0161 - val_loss: 7.8302e-04 - val_mae: 0.0121
# Epoch 191/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0019 - mae: 0.0179 - val_loss: 0.0017 - val_mae: 0.0108
# Epoch 192/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0018 - mae: 0.0166 - val_loss: 7.4981e-04 - val_mae: 0.0135
# Epoch 193/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0019 - mae: 0.0168 - val_loss: 8.5751e-04 - val_mae: 0.0116
# Epoch 194/200
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0017 - mae: 0.0173 - val_loss: 0.0018 - val_mae: 0.0133
# Epoch 195/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0018 - mae: 0.0170 - val_loss: 9.2721e-04 - val_mae: 0.0062
# Epoch 196/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0025 - mae: 0.0181 - val_loss: 8.3805e-04 - val_mae: 0.0073
# Epoch 197/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0018 - mae: 0.0181 - val_loss: 0.0020 - val_mae: 0.0135
# Epoch 198/200
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0026 - mae: 0.0191 - val_loss: 0.0016 - val_mae: 0.0085
# Epoch 199/200
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0019 - mae: 0.0172 - val_loss: 0.0010 - val_mae: 0.0080
# Epoch 200/200
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0017 - mae: 0.0157 - val_loss: 0.0011 - val_mae: 0.0087

# %% [markdown]
# ### 9.2 Evaluación LSTM (métricas en escala original)

# %%
# ======== LSTM: desempeño en TRAIN ========

# Predicciones en ESCALA ESCALADA sobre el train
y_train_pred_lstm_scaled = model_lstm.predict(X_train_lstm).reshape(-1)
y_train_true_scaled      = y_train.reshape(-1)

# Volvemos a escala original
y_train_true_lstm = scaler.inverse_transform(
    y_train_true_scaled.reshape(-1, 1)
).reshape(-1)

y_train_pred_lstm = scaler.inverse_transform(
    y_train_pred_lstm_scaled.reshape(-1, 1)
).reshape(-1)

# Métricas en train
metrics_lstm_train = regression_metrics(y_train_true_lstm, y_train_pred_lstm)
print("LSTM – métricas TRAIN:", metrics_lstm_train)

# Gráfica histórico vs predicción en TRAIN
fig_train = plot_history_vs_pred(
    train_dates,
    y_train_true_lstm,
    y_train_pred_lstm,
    title="LSTM – Train vs predicción",
)
fig_train.show()
# Out:
# 30/30 [==============================] - 0s 5ms/step
# LSTM – métricas TRAIN: {'MAE': 28682492.03500026, 'RMSE': 73568071.24306968, 'MAPE': 12671.994743138719}

# %%
y_test_pred_lstm_scaled = model_lstm.predict(X_test_lstm).reshape(-1)
y_test_true_scaled = y_test.reshape(-1)

y_test_true_lstm = scaler.inverse_transform(y_test_true_scaled.reshape(-1, 1)).reshape(-1)
y_test_pred_lstm = scaler.inverse_transform(y_test_pred_lstm_scaled.reshape(-1, 1)).reshape(-1)

metrics_lstm = regression_metrics(y_test_true_lstm, y_test_pred_lstm)
print('LSTM – métricas test:', metrics_lstm)

fig = plot_history_vs_pred(test_dates, y_test_true_lstm, y_test_pred_lstm,
                           title='LSTM - Test vs predicción')
fig.show()
# Out:
# 7/7 [==============================] - 1s 4ms/step
# LSTM – métricas test: {'MAE': 8741909.900662638, 'RMSE': 16077336.804810558, 'MAPE': 684.3174272545418}

# %% [markdown]
# ### 9.3 Pronóstico futuro con LSTM

# %%
N_FUTURE = 30  # días de pronóstico

# Última ventana del split completo (test) ya escalado
last_window_scaled = test_scaled[-WINDOW_SIZE:]

# Usamos el predict_fn especial para LSTM
future_scaled = recursive_forecast(
    model_lstm,
    last_window_scaled,
    N_FUTURE,
    predict_fn=lstm_predict_fn,  # 👈 aquí la magia
)

# Volvemos a escala original
future_preds = scaler.inverse_transform(future_scaled.reshape(-1, 1)).reshape(-1)

last_date = series.index[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1),
                             periods=N_FUTURE, freq='D')

fig = plot_future_forecast(
    series.index,
    series.values,
    future_dates,
    future_preds,
    title=f'Pronóstico LSTM {N_FUTURE} días – estado {STATE}',
)
fig.show()
# Out:
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step

# %% [markdown]
# ## 10. Modelos Transformer

# %% [markdown]
# ### 10.1 Model

# %%
# Datos en formato (batch, timesteps, features) para el Transformer
X_train_tf = X_train.reshape(-1, WINDOW_SIZE, 1)
X_val_tf   = X_val.reshape(-1, WINDOW_SIZE, 1)
X_test_tf  = X_test.reshape(-1, WINDOW_SIZE, 1)

import tensorflow as tf
from tensorflow.keras.layers import (
    Input,
    MultiHeadAttention,
    LayerNormalization,
    GlobalAveragePooling1D,
    Dense,
    Dropout,
)
from tensorflow.keras import Model

# ================== POSITIONAL ENCODING SINUSOIDAL (CONSTANTE) ==================

# d_model tiene que coincidir con la Dense de proyección
D_MODEL = 32

POS_ENCODING = tf.constant(
    get_sinusoidal_positional_encoding(WINDOW_SIZE, D_MODEL)
)  # shape (1, WINDOW_SIZE, D_MODEL)

# ================== MODELO TRANSFORMER ==================

inputs_tf = Input(shape=(WINDOW_SIZE, 1), name="transformer_input")

# Proyección inicial a d_model = D_MODEL
x = Dense(D_MODEL, name="proj_input")(inputs_tf)   # (batch, T, D_MODEL)

# Sumamos el positional encoding precomputado: shape (1, T, D_MODEL)
x = x + POS_ENCODING   # broadcasting a (batch, T, D_MODEL)

# === BLOQUE TRANSFORMER 1 (self-attention + feed-forward) ===

# Self-attention (8 cabezas, key_dim = D_MODEL)
attn1 = MultiHeadAttention(
    num_heads=4,
    key_dim=D_MODEL,
    name="mha_1"
)(x, x)
attn1 = Dropout(0.1, name="drop_attn_1")(attn1)

# Residual + norm
out1 = LayerNormalization(epsilon=1e-6, name="ln_attn_1")(x + attn1)

# Feed-forward interno: primero ampliamos, luego volvemos a D_MODEL
ff1 = Dense(2 * D_MODEL, activation="relu", name="ffn1_1")(out1)  # 256
ff1 = Dropout(0.1, name="drop_ffn_1")(ff1)
ff1 = Dense(D_MODEL, name="ffn1_2")(ff1)                          # 128

# Residual + norm (ahora las dims sí coinciden)
x = LayerNormalization(epsilon=1e-6, name="ln_ffn_1")(out1 + ff1)

# === FIN BLOQUE TRANSFORMER ===

# Pooling temporal
x = GlobalAveragePooling1D(name="gap")(x)

# Capas densas de salida
x = Dense(32, activation="relu", name="dense_out")(x)
outputs_tf = Dense(HORIZON, name="output")(x)

model_tf = Model(inputs=inputs_tf, outputs=outputs_tf, name="ts_transformer_simple")

model_tf.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss="mse",
    metrics=["mae"],
)

model_tf.summary()
# Out:
# Model: "ts_transformer_simple"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  transformer_input (InputLayer)  [(None, 7, 1)]      0           []
#
#  proj_input (Dense)             (None, 7, 32)        64          ['transformer_input[0][0]']
#
#  tf.__operators__.add_30 (TFOpL  (None, 7, 32)       0           ['proj_input[0][0]']
#  ambda)
#
#  mha_1 (MultiHeadAttention)     (None, 7, 32)        16800       ['tf.__operators__.add_30[0][0]',
#                                                                   'tf.__operators__.add_30[0][0]']
#
#  drop_attn_1 (Dropout)          (None, 7, 32)        0           ['mha_1[0][0]']
#
#  tf.__operators__.add_31 (TFOpL  (None, 7, 32)       0           ['tf.__operators__.add_30[0][0]',
#  ambda)                                                           'drop_attn_1[0][0]']
#
#  ln_attn_1 (LayerNormalization)  (None, 7, 32)       64          ['tf.__operators__.add_31[0][0]']
#
#  ffn1_1 (Dense)                 (None, 7, 64)        2112        ['ln_attn_1[0][0]']
#
#  drop_ffn_1 (Dropout)           (None, 7, 64)        0           ['ffn1_1[0][0]']
#
#  ffn1_2 (Dense)                 (None, 7, 32)        2080        ['drop_ffn_1[0][0]']
#
#  tf.__operators__.add_32 (TFOpL  (None, 7, 32)       0           ['ln_attn_1[0][0]',
#  ambda)                                                           'ffn1_2[0][0]']
#
#  ln_ffn_1 (LayerNormalization)  (None, 7, 32)        64          ['tf.__operators__.add_32[0][0]']
#
#  gap (GlobalAveragePooling1D)   (None, 32)           0           ['ln_ffn_1[0][0]']
#
#  dense_out (Dense)              (None, 32)           1056        ['gap[0][0]']
#
#  output (Dense)                 (None, 1)            33          ['dense_out[0][0]']
#
# ==================================================================================================
# Total params: 22,273
# Trainable params: 22,273
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history_tf = model_tf.fit(
    X_train_tf,
    y_train,
    validation_data=(X_val_tf, y_val),
    epochs=200,
    batch_size=32,
    verbose=1,
)
# Out:
# Epoch 1/200
# 30/30 [==============================] - 2s 23ms/step - loss: 0.0368 - mae: 0.1325 - val_loss: 8.3411e-04 - val_mae: 0.0245
# Epoch 2/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0057 - mae: 0.0476 - val_loss: 5.2325e-04 - val_mae: 0.0116
# Epoch 3/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0048 - mae: 0.0428 - val_loss: 5.7749e-04 - val_mae: 0.0137
# Epoch 4/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0052 - mae: 0.0422 - val_loss: 0.0026 - val_mae: 0.0470
# Epoch 5/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0050 - mae: 0.0424 - val_loss: 0.0010 - val_mae: 0.0250
# Epoch 6/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0044 - mae: 0.0388 - val_loss: 4.0088e-04 - val_mae: 0.0043
# Epoch 7/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0045 - mae: 0.0404 - val_loss: 8.6755e-04 - val_mae: 0.0218
# Epoch 8/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0042 - mae: 0.0363 - val_loss: 4.0874e-04 - val_mae: 0.0084
# Epoch 9/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0041 - mae: 0.0359 - val_loss: 7.1864e-04 - val_mae: 0.0215
# Epoch 10/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0039 - mae: 0.0344 - val_loss: 6.2709e-04 - val_mae: 0.0188
# Epoch 11/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0041 - mae: 0.0347 - val_loss: 0.0016 - val_mae: 0.0345
# Epoch 12/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0038 - mae: 0.0340 - val_loss: 4.2628e-04 - val_mae: 0.0063
# Epoch 13/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0038 - mae: 0.0327 - val_loss: 5.5988e-04 - val_mae: 0.0130
# Epoch 14/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0034 - mae: 0.0288 - val_loss: 4.4975e-04 - val_mae: 0.0081
# Epoch 15/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0033 - mae: 0.0292 - val_loss: 0.0012 - val_mae: 0.0323
# Epoch 16/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0035 - mae: 0.0296 - val_loss: 5.2660e-04 - val_mae: 0.0118
# Epoch 17/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0272 - val_loss: 4.0246e-04 - val_mae: 0.0054
# Epoch 18/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0033 - mae: 0.0269 - val_loss: 4.0457e-04 - val_mae: 0.0058
# Epoch 19/200
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0035 - mae: 0.0293 - val_loss: 4.9163e-04 - val_mae: 0.0132
# Epoch 20/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0034 - mae: 0.0303 - val_loss: 5.2598e-04 - val_mae: 0.0119
# Epoch 21/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0033 - mae: 0.0263 - val_loss: 4.4110e-04 - val_mae: 0.0101
# Epoch 22/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0035 - mae: 0.0297 - val_loss: 5.9364e-04 - val_mae: 0.0144
# Epoch 23/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0038 - mae: 0.0337 - val_loss: 4.0757e-04 - val_mae: 0.0064
# Epoch 24/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0034 - mae: 0.0280 - val_loss: 4.3676e-04 - val_mae: 0.0097
# Epoch 25/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0035 - mae: 0.0285 - val_loss: 8.4390e-04 - val_mae: 0.0211
# Epoch 26/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0037 - mae: 0.0330 - val_loss: 5.0077e-04 - val_mae: 0.0135
# Epoch 27/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0032 - mae: 0.0239 - val_loss: 5.8208e-04 - val_mae: 0.0168
# Epoch 28/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0033 - mae: 0.0271 - val_loss: 4.1662e-04 - val_mae: 0.0070
# Epoch 29/200
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0031 - mae: 0.0255 - val_loss: 5.1553e-04 - val_mae: 0.0139
# Epoch 30/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0030 - mae: 0.0241 - val_loss: 4.3757e-04 - val_mae: 0.0089
# Epoch 31/200
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0035 - mae: 0.0302 - val_loss: 0.0012 - val_mae: 0.0278
# Epoch 32/200
# 30/30 [==============================] - 0s 13ms/step - loss: 0.0032 - mae: 0.0255 - val_loss: 9.0383e-04 - val_mae: 0.0255
# Epoch 33/200
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0031 - mae: 0.0243 - val_loss: 4.5585e-04 - val_mae: 0.0082
# Epoch 34/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0031 - mae: 0.0256 - val_loss: 4.2571e-04 - val_mae: 0.0054
# Epoch 35/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0242 - val_loss: 4.2185e-04 - val_mae: 0.0049
# Epoch 36/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0032 - mae: 0.0247 - val_loss: 4.5350e-04 - val_mae: 0.0098
# Epoch 37/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0034 - mae: 0.0289 - val_loss: 6.3874e-04 - val_mae: 0.0159
# Epoch 38/200
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0031 - mae: 0.0252 - val_loss: 0.0017 - val_mae: 0.0394
# Epoch 39/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0033 - mae: 0.0276 - val_loss: 8.4512e-04 - val_mae: 0.0214
# Epoch 40/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0244 - val_loss: 0.0015 - val_mae: 0.0359
# Epoch 41/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0032 - mae: 0.0267 - val_loss: 0.0018 - val_mae: 0.0396
# Epoch 42/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0032 - mae: 0.0270 - val_loss: 4.6642e-04 - val_mae: 0.0084
# Epoch 43/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0031 - mae: 0.0256 - val_loss: 5.0856e-04 - val_mae: 0.0108
# Epoch 44/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0031 - mae: 0.0238 - val_loss: 4.2487e-04 - val_mae: 0.0051
# Epoch 45/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0032 - mae: 0.0267 - val_loss: 0.0013 - val_mae: 0.0331
# Epoch 46/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0035 - mae: 0.0314 - val_loss: 0.0022 - val_mae: 0.0453
# Epoch 47/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0034 - mae: 0.0302 - val_loss: 0.0011 - val_mae: 0.0285
# Epoch 48/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0032 - mae: 0.0286 - val_loss: 0.0022 - val_mae: 0.0419
# Epoch 49/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0032 - mae: 0.0276 - val_loss: 4.7952e-04 - val_mae: 0.0091
# Epoch 50/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0030 - mae: 0.0233 - val_loss: 6.6488e-04 - val_mae: 0.0167
# Epoch 51/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0032 - mae: 0.0273 - val_loss: 4.4024e-04 - val_mae: 0.0060
# Epoch 52/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0031 - mae: 0.0260 - val_loss: 5.9572e-04 - val_mae: 0.0167
# Epoch 53/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0029 - mae: 0.0229 - val_loss: 5.5922e-04 - val_mae: 0.0129
# Epoch 54/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0031 - mae: 0.0254 - val_loss: 5.0292e-04 - val_mae: 0.0103
# Epoch 55/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0031 - mae: 0.0271 - val_loss: 0.0013 - val_mae: 0.0300
# Epoch 56/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0032 - mae: 0.0266 - val_loss: 6.5776e-04 - val_mae: 0.0187
# Epoch 57/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0030 - mae: 0.0219 - val_loss: 0.0013 - val_mae: 0.0328
# Epoch 58/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0036 - mae: 0.0331 - val_loss: 0.0014 - val_mae: 0.0346
# Epoch 59/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0033 - mae: 0.0319 - val_loss: 9.4045e-04 - val_mae: 0.0234
# Epoch 60/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0032 - mae: 0.0273 - val_loss: 4.6209e-04 - val_mae: 0.0097
# Epoch 61/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0030 - mae: 0.0257 - val_loss: 0.0011 - val_mae: 0.0288
# Epoch 62/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0261 - val_loss: 5.9738e-04 - val_mae: 0.0167
# Epoch 63/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0215 - val_loss: 4.7833e-04 - val_mae: 0.0108
# Epoch 64/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0217 - val_loss: 5.0896e-04 - val_mae: 0.0105
# Epoch 65/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0251 - val_loss: 7.7090e-04 - val_mae: 0.0195
# Epoch 66/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0222 - val_loss: 0.0025 - val_mae: 0.0486
# Epoch 67/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0035 - mae: 0.0304 - val_loss: 4.3628e-04 - val_mae: 0.0064
# Epoch 68/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0251 - val_loss: 5.1827e-04 - val_mae: 0.0108
# Epoch 69/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0259 - val_loss: 5.8114e-04 - val_mae: 0.0136
# Epoch 70/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0239 - val_loss: 5.0577e-04 - val_mae: 0.0125
# Epoch 71/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0030 - mae: 0.0232 - val_loss: 8.4281e-04 - val_mae: 0.0236
# Epoch 72/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0230 - val_loss: 4.8681e-04 - val_mae: 0.0112
# Epoch 73/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0029 - mae: 0.0242 - val_loss: 0.0011 - val_mae: 0.0294
# Epoch 74/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0030 - mae: 0.0245 - val_loss: 4.7281e-04 - val_mae: 0.0098
# Epoch 75/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0032 - mae: 0.0281 - val_loss: 5.4154e-04 - val_mae: 0.0142
# Epoch 76/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0030 - mae: 0.0238 - val_loss: 7.3585e-04 - val_mae: 0.0185
# Epoch 77/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0030 - mae: 0.0261 - val_loss: 7.1720e-04 - val_mae: 0.0203
# Epoch 78/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0227 - val_loss: 4.6448e-04 - val_mae: 0.0099
# Epoch 79/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0035 - mae: 0.0332 - val_loss: 0.0010 - val_mae: 0.0255
# Epoch 80/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0245 - val_loss: 8.2115e-04 - val_mae: 0.0207
# Epoch 81/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0029 - mae: 0.0231 - val_loss: 0.0017 - val_mae: 0.0388
# Epoch 82/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0227 - val_loss: 4.5871e-04 - val_mae: 0.0095
# Epoch 83/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0233 - val_loss: 5.8829e-04 - val_mae: 0.0160
# Epoch 84/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0231 - val_loss: 5.5710e-04 - val_mae: 0.0126
# Epoch 85/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0034 - mae: 0.0321 - val_loss: 8.7991e-04 - val_mae: 0.0247
# Epoch 86/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0219 - val_loss: 4.7666e-04 - val_mae: 0.0106
# Epoch 87/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0217 - val_loss: 0.0012 - val_mae: 0.0310
# Epoch 88/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0235 - val_loss: 4.5826e-04 - val_mae: 0.0088
# Epoch 89/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0201 - val_loss: 4.5420e-04 - val_mae: 0.0067
# Epoch 90/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0213 - val_loss: 5.4132e-04 - val_mae: 0.0119
# Epoch 91/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0221 - val_loss: 0.0012 - val_mae: 0.0279
# Epoch 92/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0032 - mae: 0.0274 - val_loss: 4.4951e-04 - val_mae: 0.0083
# Epoch 93/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0227 - val_loss: 6.3267e-04 - val_mae: 0.0179
# Epoch 94/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0223 - val_loss: 8.1191e-04 - val_mae: 0.0229
# Epoch 95/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0238 - val_loss: 0.0012 - val_mae: 0.0314
# Epoch 96/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0233 - val_loss: 8.7604e-04 - val_mae: 0.0244
# Epoch 97/200
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0028 - mae: 0.0221 - val_loss: 5.8869e-04 - val_mae: 0.0137
# Epoch 98/200
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0029 - mae: 0.0232 - val_loss: 6.3039e-04 - val_mae: 0.0153
# Epoch 99/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0243 - val_loss: 0.0016 - val_mae: 0.0375
# Epoch 100/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0030 - mae: 0.0237 - val_loss: 6.3249e-04 - val_mae: 0.0178
# Epoch 101/200
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0029 - mae: 0.0228 - val_loss: 5.0892e-04 - val_mae: 0.0130
# Epoch 102/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0321 - val_loss: 0.0018 - val_mae: 0.0381
# Epoch 103/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0229 - val_loss: 8.1517e-04 - val_mae: 0.0232
# Epoch 104/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0251 - val_loss: 4.4169e-04 - val_mae: 0.0056
# Epoch 105/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0202 - val_loss: 0.0018 - val_mae: 0.0401
# Epoch 106/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0224 - val_loss: 4.5728e-04 - val_mae: 0.0073
# Epoch 107/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0242 - val_loss: 5.6154e-04 - val_mae: 0.0151
# Epoch 108/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0212 - val_loss: 4.3818e-04 - val_mae: 0.0054
# Epoch 109/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0209 - val_loss: 9.9613e-04 - val_mae: 0.0272
# Epoch 110/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0032 - mae: 0.0301 - val_loss: 9.4415e-04 - val_mae: 0.0235
# Epoch 111/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0234 - val_loss: 6.2381e-04 - val_mae: 0.0175
# Epoch 112/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0203 - val_loss: 4.3090e-04 - val_mae: 0.0064
# Epoch 113/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0192 - val_loss: 7.2973e-04 - val_mae: 0.0208
# Epoch 114/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0215 - val_loss: 6.6115e-04 - val_mae: 0.0186
# Epoch 115/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0212 - val_loss: 4.3773e-04 - val_mae: 0.0076
# Epoch 116/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0250 - val_loss: 6.3326e-04 - val_mae: 0.0179
# Epoch 117/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0247 - val_loss: 5.1946e-04 - val_mae: 0.0136
# Epoch 118/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0032 - mae: 0.0280 - val_loss: 9.9488e-04 - val_mae: 0.0246
# Epoch 119/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0250 - val_loss: 6.8121e-04 - val_mae: 0.0197
# Epoch 120/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0275 - val_loss: 7.9048e-04 - val_mae: 0.0200
# Epoch 121/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0251 - val_loss: 7.8613e-04 - val_mae: 0.0225
# Epoch 122/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0205 - val_loss: 6.2528e-04 - val_mae: 0.0179
# Epoch 123/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0027 - mae: 0.0208 - val_loss: 6.9336e-04 - val_mae: 0.0198
# Epoch 124/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0234 - val_loss: 9.0645e-04 - val_mae: 0.0253
# Epoch 125/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0246 - val_loss: 6.1402e-04 - val_mae: 0.0148
# Epoch 126/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0247 - val_loss: 0.0014 - val_mae: 0.0348
# Epoch 127/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0243 - val_loss: 5.4445e-04 - val_mae: 0.0123
# Epoch 128/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0232 - val_loss: 4.2551e-04 - val_mae: 0.0056
# Epoch 129/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0204 - val_loss: 7.9105e-04 - val_mae: 0.0226
# Epoch 130/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0035 - mae: 0.0339 - val_loss: 5.0269e-04 - val_mae: 0.0131
# Epoch 131/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0209 - val_loss: 8.1905e-04 - val_mae: 0.0207
# Epoch 132/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0210 - val_loss: 4.2506e-04 - val_mae: 0.0053
# Epoch 133/200
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0027 - mae: 0.0201 - val_loss: 4.7876e-04 - val_mae: 0.0092
# Epoch 134/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0209 - val_loss: 7.9339e-04 - val_mae: 0.0201
# Epoch 135/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0270 - val_loss: 7.3242e-04 - val_mae: 0.0210
# Epoch 136/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0229 - val_loss: 4.2716e-04 - val_mae: 0.0054
# Epoch 137/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0221 - val_loss: 4.2700e-04 - val_mae: 0.0080
# Epoch 138/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0217 - val_loss: 7.0170e-04 - val_mae: 0.0203
# Epoch 139/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0033 - mae: 0.0295 - val_loss: 5.6585e-04 - val_mae: 0.0132
# Epoch 140/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0214 - val_loss: 4.2414e-04 - val_mae: 0.0072
# Epoch 141/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0209 - val_loss: 6.3289e-04 - val_mae: 0.0156
# Epoch 142/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0247 - val_loss: 7.3303e-04 - val_mae: 0.0212
# Epoch 143/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0191 - val_loss: 0.0011 - val_mae: 0.0296
# Epoch 144/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0205 - val_loss: 4.3509e-04 - val_mae: 0.0083
# Epoch 145/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0209 - val_loss: 8.1318e-04 - val_mae: 0.0231
# Epoch 146/200
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0028 - mae: 0.0243 - val_loss: 8.5026e-04 - val_mae: 0.0242
# Epoch 147/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0211 - val_loss: 0.0012 - val_mae: 0.0315
# Epoch 148/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0247 - val_loss: 4.2913e-04 - val_mae: 0.0058
# Epoch 149/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0207 - val_loss: 4.9406e-04 - val_mae: 0.0100
# Epoch 150/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0207 - val_loss: 5.1575e-04 - val_mae: 0.0112
# Epoch 151/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0217 - val_loss: 4.1799e-04 - val_mae: 0.0055
# Epoch 152/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0198 - val_loss: 0.0014 - val_mae: 0.0348
# Epoch 153/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0032 - mae: 0.0299 - val_loss: 4.3479e-04 - val_mae: 0.0066
# Epoch 154/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0224 - val_loss: 6.4003e-04 - val_mae: 0.0185
# Epoch 155/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0220 - val_loss: 6.3438e-04 - val_mae: 0.0186
# Epoch 156/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0236 - val_loss: 7.9106e-04 - val_mae: 0.0226
# Epoch 157/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0030 - mae: 0.0247 - val_loss: 9.9400e-04 - val_mae: 0.0275
# Epoch 158/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0031 - mae: 0.0249 - val_loss: 4.8944e-04 - val_mae: 0.0132
# Epoch 159/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0226 - val_loss: 4.4454e-04 - val_mae: 0.0076
# Epoch 160/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0204 - val_loss: 9.8185e-04 - val_mae: 0.0271
# Epoch 161/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0256 - val_loss: 4.6695e-04 - val_mae: 0.0085
# Epoch 162/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0218 - val_loss: 4.2432e-04 - val_mae: 0.0065
# Epoch 163/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0194 - val_loss: 4.3483e-04 - val_mae: 0.0056
# Epoch 164/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0210 - val_loss: 6.2140e-04 - val_mae: 0.0149
# Epoch 165/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0207 - val_loss: 6.3150e-04 - val_mae: 0.0177
# Epoch 166/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0213 - val_loss: 7.7203e-04 - val_mae: 0.0218
# Epoch 167/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0214 - val_loss: 9.4009e-04 - val_mae: 0.0260
# Epoch 168/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0248 - val_loss: 8.3119e-04 - val_mae: 0.0233
# Epoch 169/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0029 - mae: 0.0256 - val_loss: 4.5811e-04 - val_mae: 0.0097
# Epoch 170/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0214 - val_loss: 5.9290e-04 - val_mae: 0.0141
# Epoch 171/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0257 - val_loss: 7.4625e-04 - val_mae: 0.0215
# Epoch 172/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0221 - val_loss: 5.2263e-04 - val_mae: 0.0140
# Epoch 173/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0210 - val_loss: 0.0012 - val_mae: 0.0303
# Epoch 174/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0255 - val_loss: 7.7341e-04 - val_mae: 0.0196
# Epoch 175/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0210 - val_loss: 4.2921e-04 - val_mae: 0.0075
# Epoch 176/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0201 - val_loss: 5.9917e-04 - val_mae: 0.0170
# Epoch 177/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0220 - val_loss: 7.8547e-04 - val_mae: 0.0199
# Epoch 178/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0242 - val_loss: 4.2994e-04 - val_mae: 0.0078
# Epoch 179/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0239 - val_loss: 6.6739e-04 - val_mae: 0.0166
# Epoch 180/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0030 - mae: 0.0261 - val_loss: 4.4702e-04 - val_mae: 0.0072
# Epoch 181/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0221 - val_loss: 4.4899e-04 - val_mae: 0.0096
# Epoch 182/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0213 - val_loss: 4.5943e-04 - val_mae: 0.0111
# Epoch 183/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0221 - val_loss: 0.0011 - val_mae: 0.0299
# Epoch 184/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0197 - val_loss: 5.9486e-04 - val_mae: 0.0165
# Epoch 185/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0250 - val_loss: 6.9675e-04 - val_mae: 0.0200
# Epoch 186/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0191 - val_loss: 4.3316e-04 - val_mae: 0.0063
# Epoch 187/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0192 - val_loss: 8.6497e-04 - val_mae: 0.0244
# Epoch 188/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0233 - val_loss: 0.0010 - val_mae: 0.0284
# Epoch 189/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0030 - mae: 0.0245 - val_loss: 4.2575e-04 - val_mae: 0.0069
# Epoch 190/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0229 - val_loss: 4.3084e-04 - val_mae: 0.0060
# Epoch 191/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0211 - val_loss: 4.4871e-04 - val_mae: 0.0074
# Epoch 192/200
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0216 - val_loss: 5.2630e-04 - val_mae: 0.0143
# Epoch 193/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0209 - val_loss: 4.1730e-04 - val_mae: 0.0055
# Epoch 194/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0223 - val_loss: 0.0014 - val_mae: 0.0317
# Epoch 195/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0237 - val_loss: 4.5213e-04 - val_mae: 0.0104
# Epoch 196/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0252 - val_loss: 5.2021e-04 - val_mae: 0.0140
# Epoch 197/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0028 - mae: 0.0241 - val_loss: 4.6606e-04 - val_mae: 0.0118
# Epoch 198/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - mae: 0.0224 - val_loss: 8.4655e-04 - val_mae: 0.0214
# Epoch 199/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0030 - mae: 0.0257 - val_loss: 5.2133e-04 - val_mae: 0.0140
# Epoch 200/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0029 - mae: 0.0251 - val_loss: 4.9575e-04 - val_mae: 0.0130

# %% [markdown]
# ### 10.2 Evaluación Transformer

# %%
# ======== Transformer: desempeño en TRAIN ========

# Predicciones en ESCALA ESCALADA sobre el train
y_train_pred_tf_scaled = model_tf.predict(X_train_tf).reshape(-1)
y_train_true_scaled    = y_train.reshape(-1)

# Volvemos a escala original
y_train_true_tf = scaler.inverse_transform(
    y_train_true_scaled.reshape(-1, 1)
).reshape(-1)

y_train_pred_tf = scaler.inverse_transform(
    y_train_pred_tf_scaled.reshape(-1, 1)
).reshape(-1)

# Métricas en train
metrics_tf_train = regression_metrics(y_train_true_tf, y_train_pred_tf)
print("Transformer - métricas TRAIN:", metrics_tf_train)

# Gráfica histórico vs predicción en TRAIN
fig_train_tf = plot_history_vs_pred(
    train_dates,
    y_train_true_tf,
    y_train_pred_tf,
    title="Transformer - Train vs predicción",
)
fig_train_tf.show()
# Out:
# 30/30 [==============================] - 0s 3ms/step
# Transformer - métricas TRAIN: {'MAE': 35976246.12788303, 'RMSE': 94031053.92194268, 'MAPE': 22007.112427898228}

# %%
# Predicciones en ESCALA ESCALADA
y_test_pred_tf_scaled = model_tf.predict(X_test_tf).reshape(-1)
y_test_true_scaled    = y_test.reshape(-1)

# Volver a escala original
y_test_true_tf = scaler.inverse_transform(
    y_test_true_scaled.reshape(-1, 1)
).reshape(-1)

y_test_pred_tf = scaler.inverse_transform(
    y_test_pred_tf_scaled.reshape(-1, 1)
).reshape(-1)

metrics_tf = regression_metrics(y_test_true_tf, y_test_pred_tf)
print("Transformer – métricas test:", metrics_tf)

fig = plot_history_vs_pred(
    test_dates,
    y_test_true_tf,
    y_test_pred_tf,
    title="Transformer - Test vs predicción",
)
fig.show()
# Out:
# 7/7 [==============================] - 0s 7ms/step
# Transformer – métricas test: {'MAE': 17246630.382432338, 'RMSE': 21337433.576958414, 'MAPE': 1453.3578277882584}

# %% [markdown]
# ### 10.3 Pronostico Futuro

# %%
N_FUTURE_TF = 30  # días de pronóstico con Transformer

last_window_scaled_tf = test_scaled[-WINDOW_SIZE:]

future_scaled_tf = recursive_forecast(
    model_tf,
    last_window_scaled_tf,
    N_FUTURE_TF,
    predict_fn=transformer_predict_fn,
)

future_preds_tf = scaler.inverse_transform(
    future_scaled_tf.reshape(-1, 1)
).reshape(-1)

last_date = series.index[-1]
future_dates_tf = pd.date_range(
    start=last_date + pd.Timedelta(days=1),
    periods=N_FUTURE_TF,
    freq="D",
)

fig = plot_future_forecast(
    series.index,
    series.values,
    future_dates_tf,
    future_preds_tf,
    title=f"Pronóstico Transformer {N_FUTURE_TF} días – estado {STATE}",
)
fig.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step

# %% [markdown]
# ## 15. Conclusiones y hallazgos
#
# Deja este bloque para redactar al final del examen:
# - Comportamiento de la serie del estado base.
# - Comparación baseline vs LSTM.
# - Limitaciones del enfoque.
# - Cómo se podría extender de forma robusta a un modelo multi-estado.
